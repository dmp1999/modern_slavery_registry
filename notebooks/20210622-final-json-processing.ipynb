# %%
# use if autocompletion is not working
# %config Completer.use_jedi = False

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import pandas as pd
import json
from tqdm import tqdm

from typing import List
import re
import numpy as np
from datetime import date
from copy import deepcopy

# %%
from modern_slavery_registry import get_root_path

# %%
PROJECT_PATH = get_root_path()
DATA_PATH = os.path.join(PROJECT_PATH, "data")
SHEETS_PATH = os.path.join(PROJECT_PATH, "data", "sheets")

# %%
os.listdir(SHEETS_PATH)
# Out:
# ['.ipynb_checkpoints',
#  'Continents_to_CountryNames.csv',
#  'fuzzy_matches.xlsx',
#  'combined_modern_slavery_statements.xlsx',
#  'modern_slavery_dataset.csv',
#  'modern_slavery_dataset_nitin.xlsx',
#  'subset_data.xlsx',
#  'CountryCodes_to_CountryNames.csv',
#  'subset_data_v3.xlsx',
#  'subset_data_v2.xlsx',
#  'ext_shawn_creds.csv']

# %% [markdown]
# ## Data - AWS

# %%
aws_df = pd.read_csv(os.path.join(SHEETS_PATH, "modern_slavery_dataset.csv"))
aws_df.head()
# Out:
#    Company ID                              Company Is Publisher  Statement ID  \
# 0        7676      "K" Line Holding Europe Limited         True       35092.0
# 1       28660  "K" Line Bulk Shipping (UK) Limited        False       35092.0
# 2       28659            "K" Line (Europe) Limited        False       35092.0
# 3       28661        "K" Line LNG Shipping Limited        False       35092.0
# 4       28658      Polar LNG Shipping (UK) Limited        False       35092.0
#
#                                                  URL Override URL  \
# 0  https://img1.wsimg.com/blobby/go/7695baff-3f0f...          NaN
# 1  https://img1.wsimg.com/blobby/go/7695baff-3f0f...          NaN
# 2  https://img1.wsimg.com/blobby/go/7695baff-3f0f...          NaN
# 3  https://img1.wsimg.com/blobby/go/7695baff-3f0f...          NaN
# 4  https://img1.wsimg.com/blobby/go/7695baff-3f0f...          NaN
#
#   Companies House Number Industry              HQ Is Also Covered  \
# 0               05005018   Marine  United Kingdom           False
# 1               04830352   Marine  United Kingdom            True
# 2               05639474   Marine  United Kingdom            True
# 3                    NaN   Marine  United Kingdom            True
# 4               02205323   Marine  United Kingdom            True
#
#   UK Modern Slavery Act California Transparency in Supply Chains Act  \
# 0                  True                                        False
# 1                  True                                        False
# 2                  True                                        False
# 3                  True                                        False
# 4                  True                                        False
#
#   Australia Modern Slavery Act Period Covered  \
# 0                        False      2018-2019
# 1                        False      2018-2019
# 2                        False      2018-2019
# 3                        False      2018-2019
# 4                        False      2018-2019
#
#                                                 Text
# 0  K LINE\nHOLDINC (EUROPE) LTD.\nModern Slavery ...
# 1  K LINE\nHOLDINC (EUROPE) LTD.\nModern Slavery ...
# 2  K LINE\nHOLDINC (EUROPE) LTD.\nModern Slavery ...
# 3  K LINE\nHOLDINC (EUROPE) LTD.\nModern Slavery ...
# 4  K LINE\nHOLDINC (EUROPE) LTD.\nModern Slavery ...

# %% [markdown]
# ## Data - ours
#
# Same columns as in AWS data

# %%
# Picking last year for every statement
our_df_unclean = pd.read_excel(
    os.path.join(SHEETS_PATH, "modern_slavery_dataset_nitin.xlsx"))

years_fixed = []
for year in our_df_unclean["Period Covered"]:
    if year is None:
        years_fixed.append(None)
        continue
    else:
        year = np.sort(str(year).split("-"))
        years_fixed.append(year[-1])
our_df_unclean["Period Covered"] = years_fixed
del years_fixed

our_df_unclean.head()
# Out:
#    Company ID                              Company  Is Publisher  \
# 0        7676      "K" Line Holding Europe Limited          True
# 1       28660  "K" Line Bulk Shipping (UK) Limited         False
# 2       28659            "K" Line (Europe) Limited         False
# 3       28661        "K" Line LNG Shipping Limited         False
# 4       28658      Polar LNG Shipping (UK) Limited         False
#
#    Statement ID                                                URL  \
# 0         35092  https://img1.wsimg.com/blobby/go/7695baff-3f0f...
# 1         35092  https://img1.wsimg.com/blobby/go/7695baff-3f0f...
# 2         35092  https://img1.wsimg.com/blobby/go/7695baff-3f0f...
# 3         35092  https://img1.wsimg.com/blobby/go/7695baff-3f0f...
# 4         35092  https://img1.wsimg.com/blobby/go/7695baff-3f0f...
#
#   Override URL Companies House Number Industry              HQ  \
# 0          NaN               05005018   Marine  United Kingdom
# 1          NaN               04830352   Marine  United Kingdom
# 2          NaN               05639474   Marine  United Kingdom
# 3          NaN                    NaN   Marine  United Kingdom
# 4          NaN               02205323   Marine  United Kingdom
#
#    Is Also Covered  UK Modern Slavery Act  \
# 0            False                   True
# 1             True                   True
# 2             True                   True
# 3             True                   True
# 4             True                   True
#
#    California Transparency in Supply Chains Act  Australia Modern Slavery Act  \
# 0                                         False                         False
# 1                                         False                         False
# 2                                         False                         False
# 3                                         False                         False
# 4                                         False                         False
#
#   Period Covered                                          statement
# 0           2019  66 99 “K” Line Holding (Europe) Limited kM K L...
# 1           2019  66 99 “K” Line Holding (Europe) Limited kM K L...
# 2           2019  66 99 “K” Line Holding (Europe) Limited kM K L...
# 3           2019  66 99 “K” Line Holding (Europe) Limited kM K L...
# 4           2019  66 99 “K” Line Holding (Europe) Limited kM K L...

# %% [markdown]
# ### Data(cleaned version and with additional information) - ours

# %%
our_df_clean = pd.read_json(os.path.join(DATA_PATH, "subset-data-with-additional-info-v3.json"))
our_df_clean.drop(["years_with_and_without_act", "years_with_act", "len(final_statement_cleaned)"], axis=1, inplace=True)
our_df_clean.head()
# Out:
#                                                  URL  \
# 0  https://1spatial.com/who-we-are/legal/modern-s...
# 1  https://www.shazans.com/slavery-and-human-traf...
# 2  https://www.business-humanrights.org/sites/def...
# 3  https://www.2agriculture.com/wp-content/upload...
# 4  https://www.2agriculture.com/wp-content/upload...
#
#                       Company  \
# 0                1Spatial Plc
# 1         1Stop Halal Limited
# 2  1st Step Solutions Limited
# 3       2 Agriculture Limited
# 4       2 Agriculture Limited
#
#                                      final_statement  \
# 0  1Spatial Modern Slavery Act Policy Statement H...
# 1  Slavery and Human Trafficking Statement – Shaz...
# 2  7/28/2019 Modern Slavery Statement 2018 - 1st ...
# 3  fh Modern Slavery Act 2015: slavery and human ...
# 4  1 Modern Slavery Act 2015: slavery and human t...
#
#                              final_statement_cleaned  \
# 0  home solution government boundary law enforcem...
# 1  shazans shazan food continue monitor covid 19 ...
# 2  28 2019 2018 statement make pursuant sec 54 20...
# 3  fh 2015 introduction uk act require business s...
# 4  2015 introduction uk act require business stat...
#
#                                      additional_info
# 0  {'id': ['903081'], 'headquarters': ['GB'], 'se...
# 1  {'id': ['903810'], 'headquarters': ['GB'], 'se...
# 2  {'id': ['900634'], 'headquarters': ['GB'], 'se...
# 3  {'id': ['901400'], 'headquarters': ['GB'], 'se...
# 4  {'id': ['901400'], 'headquarters': ['GB'], 'se...

# %%
## combining uncleaned/aws and cleaned dfs 
cols_to_keep = [
    "statement",
    "Company", 
    "Industry",
    "HQ",
    "UK Modern Slavery Act",
    "California Transparency in Supply Chains Act",
    "Australia Modern Slavery Act",
    "Period Covered"]

our_df_unclean = our_df_unclean[cols_to_keep]
our_df_unclean.columns = ["FS_" + col.lower().replace(" ", "_") for col in our_df_unclean.columns]

final_df = pd.merge(
    our_df_clean[["final_statement", "Company", "final_statement_cleaned"]],
    our_df_unclean[~our_df_unclean["FS_statement"].isna()],
    left_on=["final_statement", "Company"],
    right_on=["FS_statement", "FS_company"], 
    how="left").drop_duplicates()
final_df.drop(["FS_statement", "FS_company"], axis=1, inplace=True)
final_df.head()
# Out:
#                                      final_statement  \
# 0  1Spatial Modern Slavery Act Policy Statement H...
# 1  Slavery and Human Trafficking Statement – Shaz...
# 2  7/28/2019 Modern Slavery Statement 2018 - 1st ...
# 3  fh Modern Slavery Act 2015: slavery and human ...
# 4  1 Modern Slavery Act 2015: slavery and human t...
#
#                       Company  \
# 0                1Spatial Plc
# 1         1Stop Halal Limited
# 2  1st Step Solutions Limited
# 3       2 Agriculture Limited
# 4       2 Agriculture Limited
#
#                              final_statement_cleaned            FS_industry  \
# 0  home solution government boundary law enforcem...               Software
# 1  shazans shazan food continue monitor covid 19 ...          Food Products
# 2  28 2019 2018 statement make pursuant sec 54 20...  Professional Services
# 3  fh 2015 introduction uk act require business s...          Food Products
# 4  2015 introduction uk act require business stat...          Food Products
#
#             FS_hq FS_uk_modern_slavery_act  \
# 0  United Kingdom                     True
# 1  United Kingdom                     True
# 2  United Kingdom                     True
# 3  United Kingdom                     True
# 4  United Kingdom                     True
#
#   FS_california_transparency_in_supply_chains_act  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#   FS_australia_modern_slavery_act FS_period_covered
# 0                           False              2017
# 1                           False              2018
# 2                           False              2018
# 3                           False              2018
# 4                           False              2017

# %%
final_df["FS_period_covered"].value_counts(dropna=False)
# Out:
# 2018    3079
# 2016    2777
# 2019    2204
# 2017    1761
# NaN      693
# nan      404
# 2020     309
# 2015      23
# 2014      10
# 2021       5
# Name: FS_period_covered, dtype: int64

# %%
# bringing data at statement level
final_dict_1 = {}
for stat in tqdm(final_df["final_statement_cleaned"].unique(), leave=False, position=0):
    rows = final_df[final_df["final_statement_cleaned"]==stat].to_dict("list")
    
    n = len(rows["final_statement"])
    keys = list(rows.keys())
    keys.remove("final_statement_cleaned")
#     keys.remove("final_statement")
    
    processed_rows = []
    for i in range(n):
        processed_row_i = {}
        for k in keys: 
            processed_row_i[k] = rows[k][i] 
        
        processed_rows.append(processed_row_i)
        
    final_dict_1[stat] = processed_rows
    
# dropping duplicate entries across any statement
final_dict_clean_1 = {}
for k, v in tqdm(final_dict_1.items(), leave=False, position=0):
    if len(v) < 1:
        continue
    else:
        v = pd.DataFrame.from_dict(v).drop_duplicates().to_dict("records")
    final_dict_clean_1[k] = v
    
del final_dict_1

# %%
# checking if a statement has 2 entries
for k, v in final_dict_clean_1.items():
    if len(v) > 1:
        print(*final_dict_clean_1[k], sep="\n")
        break
# Out:
# {'final_statement': "Modern Slavery Statement | A B Graphic International Your browser is unsupported and may have security vulnerabilities! Upgrade to a newer browser to experience this site in all it's glory. Skip to main content About Us Distributors Products Contact Us News English German Spanish French Italian Modern Slavery Statement Introduction from Anthony Gardner, Chief Executive Officer We are committed to improving our practices to combat slavery and human trafficking. This statement is made pursuant to section 54(1) of the Modern Slavery Act 2015 and constitutes the A B Graphic International Group's slavery and human trafficking statement for the financial year ending 30 April 2018 Organisation's Structure We are a provider of a range of Label Converting Machinery principally in the Label and Packaging industry. Our ultimate parent company is GHB Holding Limited whose head office is in England. The Group has in excess of 350 employees worldwide and operate in England, America, Germany, Spain, France and the Netherlands. The Group has a global annual turnover of £64m. The group structure is detailed on our website www.abgint.com. Our Business The Group’s Head Office is based in Bridlington, England. The business is operated through a number of group companies based in the countries stated above. In addition, there are number of independent distributors based throughout the world. Our Supply Chains Our supply chains include a number of PLC and SME’s. There are a number of suppliers who are based overseas. Our Policies on Slavery and Human Trafficking We are committed to ensuring that there is no modern slavery or human trafficking in our supply chains or in any part of our business. Our Anti-slavery Policy reflects our commitment to acting ethically and with integrity in all our business relationships and to implementing and enforcing effective systems and controls to ensure slavery and human trafficking is not taking place anywhere in our supply chains. Due Diligence processes for Slavery and Human Trafficking As part of our initiative to identify and mitigate risk we review our customers and supply chain on a regular basis and: We have in place systems to: Identify and assess potential risk areas in our supply chains. Mitigate the risk of slavery and human trafficking occurring in our supply chains. Monitor potential risk areas in our supply chains. Protect whistle blowers. Supplier Adherence to our Values We have zero tolerance to slavery and human trafficking. To ensure all those in our supply chain and contractors comply with our values and ethics we have in place a supply chain compliance programme. This consists of representatives from Human Resources, Procurement, Sales and Finance. Training To ensure a high level of understanding of the risks of modern slavery and human trafficking in our supply chains and our business, we provide training to our staff. Our Effectiveness in Combating Slavery and Human Trafficking We have close relationships with our customers and supply chain and require them and other relevant parties to immediately advise us if they become aware of any breach or suspected breach. Our customers and supply chain are regularly visited by company representatives. Signed Anthony Gardner Chief Executive Officer A B Graphic International Group of Companies 23 September 2018 Subscribe now Sign up for our newsletter Accessibility Privacy Statement Site Map Anti-Corruption TAX EVASION Gender Pay Reporting Modern Slavery Statement English German Spanish Italian © Copyright A B Graphic International Ltd Web Design by About Us Distributors Products Contact Us Service & Support News Events Videos Vacancies Used Machines Home Accessibility Privacy Statement Site Map Anti-Corruption TAX EVASION Gender Pay Reporting Modern Slavery Statement age English age German age Spanish age age Italian", 'Company': 'A B Graphic International Ltd', 'FS_industry': 'Machinery', 'FS_hq': 'United Kingdom', 'FS_uk_modern_s ...
# {'final_statement': "Modern Slavery Statement | A B Graphic International Your browser is unsupported and may have security vulnerabilities! Upgrade to a newer browser to experience this site in all it's glory. Skip to main content About Us Distributors Products Contact Us News English German Spanish French Italian Modern Slavery Statement Introduction from Anthony Gardner, Chief Executive Officer We are committed to improving our practices to combat slavery and human trafficking. This statement is made pursuant to section 54(1) of the Modern Slavery Act 2015 and constitutes the A B Graphic International Group's slavery and human trafficking statement for the financial year ending 30 April 2018 Organisation's Structure We are a provider of a range of Label Converting Machinery principally in the Label and Packaging industry. Our ultimate parent company is GHB Holding Limited whose head office is in England. The Group has in excess of 350 employees worldwide and operate in England, America, Germany, Spain, France and the Netherlands. The Group has a global annual turnover of £64m. The group structure is detailed on our website www.abgint.com. Our Business The Group’s Head Office is based in Bridlington, England. The business is operated through a number of group companies based in the countries stated above. In addition, there are number of independent distributors based throughout the world. Our Supply Chains Our supply chains include a number of PLC and SME’s. There are a number of suppliers who are based overseas. Our Policies on Slavery and Human Trafficking We are committed to ensuring that there is no modern slavery or human trafficking in our supply chains or in any part of our business. Our Anti-slavery Policy reflects our commitment to acting ethically and with integrity in all our business relationships and to implementing and enforcing effective systems and controls to ensure slavery and human trafficking is not taking place anywhere in our supply chains. Due Diligence processes for Slavery and Human Trafficking As part of our initiative to identify and mitigate risk we review our customers and supply chain on a regular basis and: We have in place systems to: Identify and assess potential risk areas in our supply chains. Mitigate the risk of slavery and human trafficking occurring in our supply chains. Monitor potential risk areas in our supply chains. Protect whistle blowers. Supplier Adherence to our Values We have zero tolerance to slavery and human trafficking. To ensure all those in our supply chain and contractors comply with our values and ethics we have in place a supply chain compliance programme. This consists of representatives from Human Resources, Procurement, Sales and Finance. Training To ensure a high level of understanding of the risks of modern slavery and human trafficking in our supply chains and our business, we provide training to our staff. Our Effectiveness in Combating Slavery and Human Trafficking We have close relationships with our customers and supply chain and require them and other relevant parties to immediately advise us if they become aware of any breach or suspected breach. Our customers and supply chain are regularly visited by company representatives. Signed Anthony Gardner Chief Executive Officer A B Graphic International Group of Companies 23 September 2018 Subscribe now Sign up for our newsletter Accessibility Privacy Statement Site Map Anti-Corruption TAX EVASION Gender Pay Reporting Modern Slavery Statement English German Spanish Italian © Copyright A B Graphic International Ltd Web Design by About Us Distributors Products Contact Us Service & Support News Events Videos Vacancies Used Machines Home Accessibility Privacy Statement Site Map Anti-Corruption TAX EVASION Gender Pay Reporting Modern Slavery Statement age English age German age Spanish age age Italian", 'Company': 'A B Graphic International Ltd', 'FS_industry': 'Machinery', 'FS_hq': 'United Kingdom', 'FS_uk_modern_s ...

# %% [markdown]
# ### Extracting years explicitly

# %%
our_df_clean.head()
# Out:
#                                                  URL  \
# 0  https://1spatial.com/who-we-are/legal/modern-s...
# 1  https://www.shazans.com/slavery-and-human-traf...
# 2  https://www.business-humanrights.org/sites/def...
# 3  https://www.2agriculture.com/wp-content/upload...
# 4  https://www.2agriculture.com/wp-content/upload...
#
#                       Company  \
# 0                1Spatial Plc
# 1         1Stop Halal Limited
# 2  1st Step Solutions Limited
# 3       2 Agriculture Limited
# 4       2 Agriculture Limited
#
#                                      final_statement  \
# 0  1Spatial Modern Slavery Act Policy Statement H...
# 1  Slavery and Human Trafficking Statement – Shaz...
# 2  7/28/2019 Modern Slavery Statement 2018 - 1st ...
# 3  fh Modern Slavery Act 2015: slavery and human ...
# 4  1 Modern Slavery Act 2015: slavery and human t...
#
#                              final_statement_cleaned  \
# 0  home solution government boundary law enforcem...
# 1  shazans shazan food continue monitor covid 19 ...
# 2  28 2019 2018 statement make pursuant sec 54 20...
# 3  fh 2015 introduction uk act require business s...
# 4  2015 introduction uk act require business stat...
#
#                                      additional_info
# 0  {'id': ['903081'], 'headquarters': ['GB'], 'se...
# 1  {'id': ['903810'], 'headquarters': ['GB'], 'se...
# 2  {'id': ['900634'], 'headquarters': ['GB'], 'se...
# 3  {'id': ['901400'], 'headquarters': ['GB'], 'se...
# 4  {'id': ['901400'], 'headquarters': ['GB'], 'se...

# %%
def extract_year(text: str) -> List[str]:
    """Extract years present in text."""
    years = set() 
    formats = [
        r"\b[0-9]{2}/[0-9]{2}/[1-2][0-9]\b", 
        r"\b[0-9]{2}/[0-9]{2}/[2][0][1][0-9]\b",
        r"\b[2][0][1][0-9]\b"]
    for f in formats:         
        for year in re.findall(f, text):
            if "/" in year:
                year = year.split("/")[-1]
                if len(year) < 4:
                    year = "20" + year 
            years.add(year)
            
    years = [year for year in years if int(year) <= date.today().year]
    return np.sort(list(years))

# %%
def find_statement_year(statement: str):
    """Find year from modern slavery statement."""
    statement = statement.lower()
    ignore_phrases = [
        r"modern slavery act [0-9]{4}", 
        r"transparency in supply chains act [0-9]{4}", 
        r"duty of diligence [0-9]{4}"]

    for phrase in ignore_phrases:
        for s in re.findall(phrase, statement):
            statement = statement.replace(s, " ")
    
    statement =  " ".join(statement.split())
    
    years = extract_year(statement)
    
    if len(years) < 1:
        return None
    
    return years[-1]

# %%
# extracting year from statements
our_df_clean["year"] = [find_statement_year(s) for s in tqdm(our_df_clean["final_statement"], leave=False, position=0)]

# %%
our_df_clean.head()
# Out:
#                                                  URL  \
# 0  https://1spatial.com/who-we-are/legal/modern-s...
# 1  https://www.shazans.com/slavery-and-human-traf...
# 2  https://www.business-humanrights.org/sites/def...
# 3  https://www.2agriculture.com/wp-content/upload...
# 4  https://www.2agriculture.com/wp-content/upload...
#
#                       Company  \
# 0                1Spatial Plc
# 1         1Stop Halal Limited
# 2  1st Step Solutions Limited
# 3       2 Agriculture Limited
# 4       2 Agriculture Limited
#
#                                      final_statement  \
# 0  1Spatial Modern Slavery Act Policy Statement H...
# 1  Slavery and Human Trafficking Statement – Shaz...
# 2  7/28/2019 Modern Slavery Statement 2018 - 1st ...
# 3  fh Modern Slavery Act 2015: slavery and human ...
# 4  1 Modern Slavery Act 2015: slavery and human t...
#
#                              final_statement_cleaned  \
# 0  home solution government boundary law enforcem...
# 1  shazans shazan food continue monitor covid 19 ...
# 2  28 2019 2018 statement make pursuant sec 54 20...
# 3  fh 2015 introduction uk act require business s...
# 4  2015 introduction uk act require business stat...
#
#                                      additional_info  year
# 0  {'id': ['903081'], 'headquarters': ['GB'], 'se...  None
# 1  {'id': ['903810'], 'headquarters': ['GB'], 'se...  2019
# 2  {'id': ['900634'], 'headquarters': ['GB'], 'se...  2019
# 3  {'id': ['901400'], 'headquarters': ['GB'], 'se...  2019
# 4  {'id': ['901400'], 'headquarters': ['GB'], 'se...  2018

# %%
our_df_clean["year"].value_counts(dropna=False)
# Out:
# 2019    5033
# 2018    1686
# NaN     1073
# 2017    1070
# 2016     421
# 2010     246
# 2015     193
# 2012     159
# 2014      44
# 2011      26
# 2020      21
# 2013      20
# 2021       1
# Name: year, dtype: int64

# %%
# bringing cleaned version data at statement level
final_dict_2 = {}
for stat in tqdm(our_df_clean["final_statement_cleaned"], leave=False, position=0):
    rows = deepcopy(our_df_clean[our_df_clean["final_statement_cleaned"]==stat])
    rows.drop(["final_statement", "final_statement_cleaned"], axis=1, inplace=True)
    rows = rows.to_dict("records")
    
    cols_to_keep = ["Company", "year", "headquarters", "sectors"]
    processed_rows = []
    for row in rows:
        row = deepcopy(row)
        info = deepcopy(row["additional_info"])

        for k,v in info.items():
            row[k] = v
        
        keys = deepcopy(list(row.keys()))
        for k in keys:
            if k not in cols_to_keep:
                del row[k]
        
        processed_rows.append(row)
        
    final_dict_2[stat] = processed_rows
    
# merging information
final_dict_clean_2 = {}
for k in tqdm(final_dict_clean_1.keys(), leave=False, position=0):
    v1 = pd.DataFrame.from_dict(final_dict_clean_1[k])
    v2 = pd.DataFrame.from_dict(final_dict_2[k])
    final_dict_clean_2[k] = pd.merge(v1, v2, on="Company", how="left").to_dict("records")
del final_dict_clean_1, final_dict_2

# %%
# checking if a statement has 2 entries
for k, v in final_dict_clean_2.items():
    if len(v) > 1:
        print(*final_dict_clean_2[k], sep="\n")
        break
# Out:
# {'final_statement': "Modern Slavery Statement | A B Graphic International Your browser is unsupported and may have security vulnerabilities! Upgrade to a newer browser to experience this site in all it's glory. Skip to main content About Us Distributors Products Contact Us News English German Spanish French Italian Modern Slavery Statement Introduction from Anthony Gardner, Chief Executive Officer We are committed to improving our practices to combat slavery and human trafficking. This statement is made pursuant to section 54(1) of the Modern Slavery Act 2015 and constitutes the A B Graphic International Group's slavery and human trafficking statement for the financial year ending 30 April 2018 Organisation's Structure We are a provider of a range of Label Converting Machinery principally in the Label and Packaging industry. Our ultimate parent company is GHB Holding Limited whose head office is in England. The Group has in excess of 350 employees worldwide and operate in England, America, Germany, Spain, France and the Netherlands. The Group has a global annual turnover of £64m. The group structure is detailed on our website www.abgint.com. Our Business The Group’s Head Office is based in Bridlington, England. The business is operated through a number of group companies based in the countries stated above. In addition, there are number of independent distributors based throughout the world. Our Supply Chains Our supply chains include a number of PLC and SME’s. There are a number of suppliers who are based overseas. Our Policies on Slavery and Human Trafficking We are committed to ensuring that there is no modern slavery or human trafficking in our supply chains or in any part of our business. Our Anti-slavery Policy reflects our commitment to acting ethically and with integrity in all our business relationships and to implementing and enforcing effective systems and controls to ensure slavery and human trafficking is not taking place anywhere in our supply chains. Due Diligence processes for Slavery and Human Trafficking As part of our initiative to identify and mitigate risk we review our customers and supply chain on a regular basis and: We have in place systems to: Identify and assess potential risk areas in our supply chains. Mitigate the risk of slavery and human trafficking occurring in our supply chains. Monitor potential risk areas in our supply chains. Protect whistle blowers. Supplier Adherence to our Values We have zero tolerance to slavery and human trafficking. To ensure all those in our supply chain and contractors comply with our values and ethics we have in place a supply chain compliance programme. This consists of representatives from Human Resources, Procurement, Sales and Finance. Training To ensure a high level of understanding of the risks of modern slavery and human trafficking in our supply chains and our business, we provide training to our staff. Our Effectiveness in Combating Slavery and Human Trafficking We have close relationships with our customers and supply chain and require them and other relevant parties to immediately advise us if they become aware of any breach or suspected breach. Our customers and supply chain are regularly visited by company representatives. Signed Anthony Gardner Chief Executive Officer A B Graphic International Group of Companies 23 September 2018 Subscribe now Sign up for our newsletter Accessibility Privacy Statement Site Map Anti-Corruption TAX EVASION Gender Pay Reporting Modern Slavery Statement English German Spanish Italian © Copyright A B Graphic International Ltd Web Design by About Us Distributors Products Contact Us Service & Support News Events Videos Vacancies Used Machines Home Accessibility Privacy Statement Site Map Anti-Corruption TAX EVASION Gender Pay Reporting Modern Slavery Statement age English age German age Spanish age age Italian", 'Company': 'A B Graphic International Ltd', 'FS_industry': 'Machinery', 'FS_hq': 'United Kingdom', 'FS_uk_modern_s ...
# {'final_statement': "Modern Slavery Statement | A B Graphic International Your browser is unsupported and may have security vulnerabilities! Upgrade to a newer browser to experience this site in all it's glory. Skip to main content About Us Distributors Products Contact Us News English German Spanish French Italian Modern Slavery Statement Introduction from Anthony Gardner, Chief Executive Officer We are committed to improving our practices to combat slavery and human trafficking. This statement is made pursuant to section 54(1) of the Modern Slavery Act 2015 and constitutes the A B Graphic International Group's slavery and human trafficking statement for the financial year ending 30 April 2018 Organisation's Structure We are a provider of a range of Label Converting Machinery principally in the Label and Packaging industry. Our ultimate parent company is GHB Holding Limited whose head office is in England. The Group has in excess of 350 employees worldwide and operate in England, America, Germany, Spain, France and the Netherlands. The Group has a global annual turnover of £64m. The group structure is detailed on our website www.abgint.com. Our Business The Group’s Head Office is based in Bridlington, England. The business is operated through a number of group companies based in the countries stated above. In addition, there are number of independent distributors based throughout the world. Our Supply Chains Our supply chains include a number of PLC and SME’s. There are a number of suppliers who are based overseas. Our Policies on Slavery and Human Trafficking We are committed to ensuring that there is no modern slavery or human trafficking in our supply chains or in any part of our business. Our Anti-slavery Policy reflects our commitment to acting ethically and with integrity in all our business relationships and to implementing and enforcing effective systems and controls to ensure slavery and human trafficking is not taking place anywhere in our supply chains. Due Diligence processes for Slavery and Human Trafficking As part of our initiative to identify and mitigate risk we review our customers and supply chain on a regular basis and: We have in place systems to: Identify and assess potential risk areas in our supply chains. Mitigate the risk of slavery and human trafficking occurring in our supply chains. Monitor potential risk areas in our supply chains. Protect whistle blowers. Supplier Adherence to our Values We have zero tolerance to slavery and human trafficking. To ensure all those in our supply chain and contractors comply with our values and ethics we have in place a supply chain compliance programme. This consists of representatives from Human Resources, Procurement, Sales and Finance. Training To ensure a high level of understanding of the risks of modern slavery and human trafficking in our supply chains and our business, we provide training to our staff. Our Effectiveness in Combating Slavery and Human Trafficking We have close relationships with our customers and supply chain and require them and other relevant parties to immediately advise us if they become aware of any breach or suspected breach. Our customers and supply chain are regularly visited by company representatives. Signed Anthony Gardner Chief Executive Officer A B Graphic International Group of Companies 23 September 2018 Subscribe now Sign up for our newsletter Accessibility Privacy Statement Site Map Anti-Corruption TAX EVASION Gender Pay Reporting Modern Slavery Statement English German Spanish Italian © Copyright A B Graphic International Ltd Web Design by About Us Distributors Products Contact Us Service & Support News Events Videos Vacancies Used Machines Home Accessibility Privacy Statement Site Map Anti-Corruption TAX EVASION Gender Pay Reporting Modern Slavery Statement age English age German age Spanish age age Italian", 'Company': 'A B Graphic International Ltd', 'FS_industry': 'Machinery', 'FS_hq': 'United Kingdom', 'FS_uk_modern_s ...

# %%
final_dict_clean_2[list(final_dict_clean_2.keys())[0]]
# Out:
# [{'final_statement': '1Spatial Modern Slavery Act Policy Statement Home Solutions Solutions Government Boundaries Law Enforcement Rural Payments Next Generation 911 Utilities ArcGIS Utility Network Accelerator Traffic Management Plan Automation (TMPA) Automated Schematics Pipe Inference Incident Management Leakage Solutions Transport and Infrastructure Supply Chain Data Quality Highway Performance Monitoring System Next Generation 911 Services Consultancy Support Training 1Spatial Training FME Training Geocortex Training "1Spatial provides excellent knowledge and support to meet our current business needs. Individuals also go the extra mile in responding to critical issues and timescales, which is always very much appreciated and essential to the continued success of our business." Danny O\'Reilly | DAERA Industries Industries Utilities Water and Wastewater Gas Electricity Telecommunications Government National Mapping Agencies Land and Environmental Management Public Sector Procurement Industries Transportation and Infrastructure Rail Roads and Highways Aeronautical Ports Maritime and Hydrographic Defence Engineering Facilities Management Services Consultancy Support Training 1Spatial Training FME Training Geocortex Training "1Spatial have helped us to find innovative solutions to some of our long-standing business problems that have then been delivered quickly and efficiently." Paul Williams | United Utilities Products Products 1Integrate 1Data Gateway 1Integrate for ArcGIS 1Edit 1Generalise 1Spatial Management Suite Location Master Data Management Location Mobile App Platform (LMAP) Elyx Suite Products FME FME Desktop FME Server FME Cloud FME Maintenance FME Tools Geocortex Services Consultancy Support Training 1Spatial Training FME Training Geocortex Training "The feedback we’ve had from the business – from management and from engineers on the ground – has been amazing, really positive. We achieved a huge amount in a very, very short space of time." Alex Hincks, Senior Project Manager | Environment Agency Clients About Us About Us Careers Location Master Data Management Our Rules-Based Approach Partners Affiliations Corporate Social Responsibility Legal Anti-Bribery Policy Statement Environmental Policy Equality & Diversity Policy Statement Health and Safety Policy Statement Modern Slavery Act Policy Statement Public Interest Disclosure (Whistleblowing) Policy Statement News Events Events Events On-Demand Webinars Investors Investors Advisors AIM 26 Rule Annual and Interim Reports Board Company Announcements Corporate Governance Shareholders Shareholder Communications Shareprice Strategy Investor Enquiries Independent Research – Edison Investments Select region UK France USA Australia Belgium Careers Contact us Home Solutions Industries Products Clients About Us News Events Investors Home Solutions Solutions Government Boundaries Law Enforcement Rural Payments Next Generation 911 Utilities ArcGIS Utility Network Accelerator Traffic Management Plan Automation (TMPA) Automated Schematics Pipe Inference Incident Management Leakage Solutions Transport and Infrastructure Supply Chain Data Quality Highway Performance Monitoring System Next Generation 911 Services Consultancy Support Training 1Spatial Training FME Training Geocortex Training "1Spatial provides excellent knowledge and support to meet our current business needs. Individuals also go the extra mile in responding to critical issues and timescales, which is always very much appreciated and essential to the continued success of our business." Danny O\'Reilly | DAERA Industries Industries Utilities Water and Wastewater Gas Electricity Telecommunications Government National Mapping Agencies Land and Environmental Management Public Sector Procurement Industries Transportation and Infrastructure Rail Roads and Highways Aeronautical Ports Maritime and Hydrographic Defence Engineering Facilities Management Services Consultancy Support Training 1Spatial Training FME Training G ...
#   'Company': '1Spatial Plc',
#   'FS_industry': 'Software',
#   'FS_hq': 'United Kingdom',
#   'FS_uk_modern_slavery_act': True,
#   'FS_california_transparency_in_supply_chains_act': False,
#   'FS_australia_modern_slavery_act': False,
#   'FS_period_covered': '2017',
#   'year': None,
#   'headquarters': ['GB'],
#   'sectors': {'Technology': ['General']}}]

# %%
with open(os.path.join(DATA_PATH, 'subset-data-with-additional-info-v5.json'), 'w') as f:
    json.dump(final_dict_clean_2, f)

# %%
with open(os.path.join(DATA_PATH, 'subset-data-with-additional-info-v5.json')) as fp:
    json_obj = json.load(fp)

# %%
json_obj[list(json_obj.keys())[0]]
# Out:
# [{'final_statement': '1Spatial Modern Slavery Act Policy Statement Home Solutions Solutions Government Boundaries Law Enforcement Rural Payments Next Generation 911 Utilities ArcGIS Utility Network Accelerator Traffic Management Plan Automation (TMPA) Automated Schematics Pipe Inference Incident Management Leakage Solutions Transport and Infrastructure Supply Chain Data Quality Highway Performance Monitoring System Next Generation 911 Services Consultancy Support Training 1Spatial Training FME Training Geocortex Training "1Spatial provides excellent knowledge and support to meet our current business needs. Individuals also go the extra mile in responding to critical issues and timescales, which is always very much appreciated and essential to the continued success of our business." Danny O\'Reilly | DAERA Industries Industries Utilities Water and Wastewater Gas Electricity Telecommunications Government National Mapping Agencies Land and Environmental Management Public Sector Procurement Industries Transportation and Infrastructure Rail Roads and Highways Aeronautical Ports Maritime and Hydrographic Defence Engineering Facilities Management Services Consultancy Support Training 1Spatial Training FME Training Geocortex Training "1Spatial have helped us to find innovative solutions to some of our long-standing business problems that have then been delivered quickly and efficiently." Paul Williams | United Utilities Products Products 1Integrate 1Data Gateway 1Integrate for ArcGIS 1Edit 1Generalise 1Spatial Management Suite Location Master Data Management Location Mobile App Platform (LMAP) Elyx Suite Products FME FME Desktop FME Server FME Cloud FME Maintenance FME Tools Geocortex Services Consultancy Support Training 1Spatial Training FME Training Geocortex Training "The feedback we’ve had from the business – from management and from engineers on the ground – has been amazing, really positive. We achieved a huge amount in a very, very short space of time." Alex Hincks, Senior Project Manager | Environment Agency Clients About Us About Us Careers Location Master Data Management Our Rules-Based Approach Partners Affiliations Corporate Social Responsibility Legal Anti-Bribery Policy Statement Environmental Policy Equality & Diversity Policy Statement Health and Safety Policy Statement Modern Slavery Act Policy Statement Public Interest Disclosure (Whistleblowing) Policy Statement News Events Events Events On-Demand Webinars Investors Investors Advisors AIM 26 Rule Annual and Interim Reports Board Company Announcements Corporate Governance Shareholders Shareholder Communications Shareprice Strategy Investor Enquiries Independent Research – Edison Investments Select region UK France USA Australia Belgium Careers Contact us Home Solutions Industries Products Clients About Us News Events Investors Home Solutions Solutions Government Boundaries Law Enforcement Rural Payments Next Generation 911 Utilities ArcGIS Utility Network Accelerator Traffic Management Plan Automation (TMPA) Automated Schematics Pipe Inference Incident Management Leakage Solutions Transport and Infrastructure Supply Chain Data Quality Highway Performance Monitoring System Next Generation 911 Services Consultancy Support Training 1Spatial Training FME Training Geocortex Training "1Spatial provides excellent knowledge and support to meet our current business needs. Individuals also go the extra mile in responding to critical issues and timescales, which is always very much appreciated and essential to the continued success of our business." Danny O\'Reilly | DAERA Industries Industries Utilities Water and Wastewater Gas Electricity Telecommunications Government National Mapping Agencies Land and Environmental Management Public Sector Procurement Industries Transportation and Infrastructure Rail Roads and Highways Aeronautical Ports Maritime and Hydrographic Defence Engineering Facilities Management Services Consultancy Support Training 1Spatial Training FME Training G ...
#   'Company': '1Spatial Plc',
#   'FS_industry': 'Software',
#   'FS_hq': 'United Kingdom',
#   'FS_uk_modern_slavery_act': True,
#   'FS_california_transparency_in_supply_chains_act': False,
#   'FS_australia_modern_slavery_act': False,
#   'FS_period_covered': '2017',
#   'year': None,
#   'headquarters': ['GB'],
#   'sectors': {'Technology': ['General']}}]

# %%
# Fixing headquaters
distinct_hq = set()
for k, list_dict in tqdm(json_obj.items(), leave=False, position=0):
    for dict_ in list_dict:
        for hq in dict_["headquarters"]:
            distinct_hq.add(hq)
            
json_obj_flat = {}
for k, list_dict in tqdm(json_obj.items(), leave=False, position=0):
    new_list_dict = []
    for dict_ in list_dict:
        new_dict_ = deepcopy(dict_)
        del new_dict_["headquarters"]
        
        for hq in distinct_hq:
            new_dict_[f"HQ_{hq}"] = 0

        for hq in dict_["headquarters"]:
            new_dict_[f"HQ_{hq}"] = 1
        new_list_dict.append(new_dict_)
    json_obj_flat[k] = new_list_dict

# %%
json_obj_flat[list(json_obj_flat.keys())[0]]
# Out:
# [{'final_statement': '1Spatial Modern Slavery Act Policy Statement Home Solutions Solutions Government Boundaries Law Enforcement Rural Payments Next Generation 911 Utilities ArcGIS Utility Network Accelerator Traffic Management Plan Automation (TMPA) Automated Schematics Pipe Inference Incident Management Leakage Solutions Transport and Infrastructure Supply Chain Data Quality Highway Performance Monitoring System Next Generation 911 Services Consultancy Support Training 1Spatial Training FME Training Geocortex Training "1Spatial provides excellent knowledge and support to meet our current business needs. Individuals also go the extra mile in responding to critical issues and timescales, which is always very much appreciated and essential to the continued success of our business." Danny O\'Reilly | DAERA Industries Industries Utilities Water and Wastewater Gas Electricity Telecommunications Government National Mapping Agencies Land and Environmental Management Public Sector Procurement Industries Transportation and Infrastructure Rail Roads and Highways Aeronautical Ports Maritime and Hydrographic Defence Engineering Facilities Management Services Consultancy Support Training 1Spatial Training FME Training Geocortex Training "1Spatial have helped us to find innovative solutions to some of our long-standing business problems that have then been delivered quickly and efficiently." Paul Williams | United Utilities Products Products 1Integrate 1Data Gateway 1Integrate for ArcGIS 1Edit 1Generalise 1Spatial Management Suite Location Master Data Management Location Mobile App Platform (LMAP) Elyx Suite Products FME FME Desktop FME Server FME Cloud FME Maintenance FME Tools Geocortex Services Consultancy Support Training 1Spatial Training FME Training Geocortex Training "The feedback we’ve had from the business – from management and from engineers on the ground – has been amazing, really positive. We achieved a huge amount in a very, very short space of time." Alex Hincks, Senior Project Manager | Environment Agency Clients About Us About Us Careers Location Master Data Management Our Rules-Based Approach Partners Affiliations Corporate Social Responsibility Legal Anti-Bribery Policy Statement Environmental Policy Equality & Diversity Policy Statement Health and Safety Policy Statement Modern Slavery Act Policy Statement Public Interest Disclosure (Whistleblowing) Policy Statement News Events Events Events On-Demand Webinars Investors Investors Advisors AIM 26 Rule Annual and Interim Reports Board Company Announcements Corporate Governance Shareholders Shareholder Communications Shareprice Strategy Investor Enquiries Independent Research – Edison Investments Select region UK France USA Australia Belgium Careers Contact us Home Solutions Industries Products Clients About Us News Events Investors Home Solutions Solutions Government Boundaries Law Enforcement Rural Payments Next Generation 911 Utilities ArcGIS Utility Network Accelerator Traffic Management Plan Automation (TMPA) Automated Schematics Pipe Inference Incident Management Leakage Solutions Transport and Infrastructure Supply Chain Data Quality Highway Performance Monitoring System Next Generation 911 Services Consultancy Support Training 1Spatial Training FME Training Geocortex Training "1Spatial provides excellent knowledge and support to meet our current business needs. Individuals also go the extra mile in responding to critical issues and timescales, which is always very much appreciated and essential to the continued success of our business." Danny O\'Reilly | DAERA Industries Industries Utilities Water and Wastewater Gas Electricity Telecommunications Government National Mapping Agencies Land and Environmental Management Public Sector Procurement Industries Transportation and Infrastructure Rail Roads and Highways Aeronautical Ports Maritime and Hydrographic Defence Engineering Facilities Management Services Consultancy Support Training 1Spatial Training FME Training G ...
#   'Company': '1Spatial Plc',
#   'FS_industry': 'Software',
#   'FS_hq': 'United Kingdom',
#   'FS_uk_modern_slavery_act': True,
#   'FS_california_transparency_in_supply_chains_act': False,
#   'FS_australia_modern_slavery_act': False,
#   'FS_period_covered': '2017',
#   'year': None,
#   'sectors': {'Technology': ['General']},
#   'HQ_Luxembourg': 0,
#   'HQ_KZ': 0,
#   'HQ_RU': 0,
#   'HQ_Spain': 0,
#   'HQ_CY': 0,
#   'HQ_US': 0,
#   'HQ_GG': 0,
#   'HQ_Taiwan': 0,
#   'HQ_KR': 0,
#   'HQ_BE': 0,
#   'HQ_VN': 0,
#   'HQ_GB': 1,
#   'HQ_LU': 0,
#   'HQ_United Arab Emirates': 0,
#   'HQ_SA': 0,
#   'HQ_HN': 0,
#   'HQ_Australia': 0,
#   'HQ_CH': 0,
#   'HQ_ZA': 0,
#   'HQ_CA': 0,
#   'HQ_QA': 0,
#   'HQ_OM': 0,
#   'HQ_NZ': 0,
#   'HQ_Finland': 0,
#   'HQ_AF': 0,
#   'HQ_IL': 0,
#   'HQ_IT': 0,
#   'HQ_SG': 0,
#   'HQ_AE': 0,
#   'HQ_TH': 0,
#   'HQ_JP': 0,
#   'HQ_NL': 0,
#   'HQ_DE': 0,
#   'HQ_Canada': 0,
#   'HQ_GL': 0,
#   'HQ_AT': 0,
#   'HQ_Ireland': 0,
#   'HQ_TW': 0,
#   'HQ_ES': 0,
#   'HQ_MY': 0,
#   'HQ_KW': 0,
#   'HQ_CN': 0,
#   'HQ_Sweden': 0,
#   'HQ_Japan': 0,
#   'HQ_FI': 0,
#   'HQ_Austria': 0,
#   'HQ_None': 0,
#   'HQ_NO': 0,
#   'HQ_PH': 0,
#   'HQ_Hong Kong': 0,
#   'HQ_AU': 0,
#   'HQ_BM': 0,
#   'HQ_MX': 0,
#   'HQ_Germany': 0,
#   'HQ_BR': 0,
#   'HQ_GE': 0,
#   'HQ_United Kingdom': 0,
#   'HQ_CL': 0,
#   'HQ_Netherlands': 0,
#   'HQ_PL': 0,
#   'HQ_United States': 0,
#   'HQ_India': 0,
#   'HQ_IE': 0,
#   'HQ_HK': 0,
#   'HQ_UG': 0,
#   'HQ_TR': 0,
#   'HQ_FR': 0,
#   'HQ_Belgium': 0,
#   'HQ_DK': 0,
#   'HQ_SE': 0,
#   'HQ_IN': 0,
#   'HQ_IO': 0,
#   'HQ_JE': 0,
#   'HQ_BH': 0}]

# %%
# Fixing sectors
distinct_sectors = set()
for k, list_dict in tqdm(json_obj.items(), leave=False, position=0):
    for dict_ in list_dict:
        for sector in dict_["sectors"].keys():
            distinct_sectors.add(sector)
            
for k, list_dict in tqdm(json_obj_flat.items(), leave=False, position=0):
    new_list_dict = []
    for dict_ in list_dict:
        new_dict_ = deepcopy(dict_)
        
        for sector in distinct_sectors:
            new_dict_[f"SECTOR_{sector}"] = 0

        for sector in dict_["sectors"].keys():
            new_dict_[f"SECTOR_{sector}"] = 1
        new_list_dict.append(new_dict_)
    json_obj_flat[k] = new_list_dict

# %%
json_obj_flat[list(json_obj_flat.keys())[0]]
# Out:
# [{'final_statement': '1Spatial Modern Slavery Act Policy Statement Home Solutions Solutions Government Boundaries Law Enforcement Rural Payments Next Generation 911 Utilities ArcGIS Utility Network Accelerator Traffic Management Plan Automation (TMPA) Automated Schematics Pipe Inference Incident Management Leakage Solutions Transport and Infrastructure Supply Chain Data Quality Highway Performance Monitoring System Next Generation 911 Services Consultancy Support Training 1Spatial Training FME Training Geocortex Training "1Spatial provides excellent knowledge and support to meet our current business needs. Individuals also go the extra mile in responding to critical issues and timescales, which is always very much appreciated and essential to the continued success of our business." Danny O\'Reilly | DAERA Industries Industries Utilities Water and Wastewater Gas Electricity Telecommunications Government National Mapping Agencies Land and Environmental Management Public Sector Procurement Industries Transportation and Infrastructure Rail Roads and Highways Aeronautical Ports Maritime and Hydrographic Defence Engineering Facilities Management Services Consultancy Support Training 1Spatial Training FME Training Geocortex Training "1Spatial have helped us to find innovative solutions to some of our long-standing business problems that have then been delivered quickly and efficiently." Paul Williams | United Utilities Products Products 1Integrate 1Data Gateway 1Integrate for ArcGIS 1Edit 1Generalise 1Spatial Management Suite Location Master Data Management Location Mobile App Platform (LMAP) Elyx Suite Products FME FME Desktop FME Server FME Cloud FME Maintenance FME Tools Geocortex Services Consultancy Support Training 1Spatial Training FME Training Geocortex Training "The feedback we’ve had from the business – from management and from engineers on the ground – has been amazing, really positive. We achieved a huge amount in a very, very short space of time." Alex Hincks, Senior Project Manager | Environment Agency Clients About Us About Us Careers Location Master Data Management Our Rules-Based Approach Partners Affiliations Corporate Social Responsibility Legal Anti-Bribery Policy Statement Environmental Policy Equality & Diversity Policy Statement Health and Safety Policy Statement Modern Slavery Act Policy Statement Public Interest Disclosure (Whistleblowing) Policy Statement News Events Events Events On-Demand Webinars Investors Investors Advisors AIM 26 Rule Annual and Interim Reports Board Company Announcements Corporate Governance Shareholders Shareholder Communications Shareprice Strategy Investor Enquiries Independent Research – Edison Investments Select region UK France USA Australia Belgium Careers Contact us Home Solutions Industries Products Clients About Us News Events Investors Home Solutions Solutions Government Boundaries Law Enforcement Rural Payments Next Generation 911 Utilities ArcGIS Utility Network Accelerator Traffic Management Plan Automation (TMPA) Automated Schematics Pipe Inference Incident Management Leakage Solutions Transport and Infrastructure Supply Chain Data Quality Highway Performance Monitoring System Next Generation 911 Services Consultancy Support Training 1Spatial Training FME Training Geocortex Training "1Spatial provides excellent knowledge and support to meet our current business needs. Individuals also go the extra mile in responding to critical issues and timescales, which is always very much appreciated and essential to the continued success of our business." Danny O\'Reilly | DAERA Industries Industries Utilities Water and Wastewater Gas Electricity Telecommunications Government National Mapping Agencies Land and Environmental Management Public Sector Procurement Industries Transportation and Infrastructure Rail Roads and Highways Aeronautical Ports Maritime and Hydrographic Defence Engineering Facilities Management Services Consultancy Support Training 1Spatial Training FME Training G ...
#   'Company': '1Spatial Plc',
#   'FS_industry': 'Software',
#   'FS_hq': 'United Kingdom',
#   'FS_uk_modern_slavery_act': True,
#   'FS_california_transparency_in_supply_chains_act': False,
#   'FS_australia_modern_slavery_act': False,
#   'FS_period_covered': '2017',
#   'year': None,
#   'sectors': {'Technology': ['General']},
#   'HQ_Luxembourg': 0,
#   'HQ_KZ': 0,
#   'HQ_RU': 0,
#   'HQ_Spain': 0,
#   'HQ_CY': 0,
#   'HQ_US': 0,
#   'HQ_GG': 0,
#   'HQ_Taiwan': 0,
#   'HQ_KR': 0,
#   'HQ_BE': 0,
#   'HQ_VN': 0,
#   'HQ_GB': 1,
#   'HQ_LU': 0,
#   'HQ_United Arab Emirates': 0,
#   'HQ_SA': 0,
#   'HQ_HN': 0,
#   'HQ_Australia': 0,
#   'HQ_CH': 0,
#   'HQ_ZA': 0,
#   'HQ_CA': 0,
#   'HQ_QA': 0,
#   'HQ_OM': 0,
#   'HQ_NZ': 0,
#   'HQ_Finland': 0,
#   'HQ_AF': 0,
#   'HQ_IL': 0,
#   'HQ_IT': 0,
#   'HQ_SG': 0,
#   'HQ_AE': 0,
#   'HQ_TH': 0,
#   'HQ_JP': 0,
#   'HQ_NL': 0,
#   'HQ_DE': 0,
#   'HQ_Canada': 0,
#   'HQ_GL': 0,
#   'HQ_AT': 0,
#   'HQ_Ireland': 0,
#   'HQ_TW': 0,
#   'HQ_ES': 0,
#   'HQ_MY': 0,
#   'HQ_KW': 0,
#   'HQ_CN': 0,
#   'HQ_Sweden': 0,
#   'HQ_Japan': 0,
#   'HQ_FI': 0,
#   'HQ_Austria': 0,
#   'HQ_None': 0,
#   'HQ_NO': 0,
#   'HQ_PH': 0,
#   'HQ_Hong Kong': 0,
#   'HQ_AU': 0,
#   'HQ_BM': 0,
#   'HQ_MX': 0,
#   'HQ_Germany': 0,
#   'HQ_BR': 0,
#   'HQ_GE': 0,
#   'HQ_United Kingdom': 0,
#   'HQ_CL': 0,
#   'HQ_Netherlands': 0,
#   'HQ_PL': 0,
#   'HQ_United States': 0,
#   'HQ_India': 0,
#   'HQ_IE': 0,
#   'HQ_HK': 0,
#   'HQ_UG': 0,
#   'HQ_TR': 0,
#   'HQ_FR': 0,
#   'HQ_Belgium': 0,
#   'HQ_DK': 0,
#   'HQ_SE': 0,
#   'HQ_IN': 0,
#   'HQ_IO': 0,
#   'HQ_JE': 0,
#   'HQ_BH': 0,
#   'SECTOR_Charity/Non-Profit': 0,
#   'SECTOR_Shipping & handling': 0,
#   'SECTOR_Household Products': 0,
#   'SECTOR_Other': 0,
#   'SECTOR_Insurance': 0,
#   'SECTOR_Construction & Engineering': 0,
#   'SECTOR_Air Freight & Logistics': 0,
#   'SECTOR_Safety/environment': 0,
#   'SECTOR_Public Entities': 0,
#   'SECTOR_Garden/landscaping': 0,
#   'SECTOR_Equity Real Estate Investment Trusts (REITs)': 0,
#   'SECTOR_Road & Rail': 0,
#   'SECTOR_Consumer products/retail': 0,
#   'SECTOR_Beverages': 0,
#   'SECTOR_Independent Power and Renewable Electricity Producers': 0,
#   'SECTOR_Construction Materials': 0,
#   'SECTOR_Diversified Consumer Services': 0,
#   'SECTOR_Thrifts & Mortgage Finance': 0,
#   'SECTOR_Construction & building materials': 0,
#   'SECTOR_Capital Markets': 0,
#   'SECTOR_Metals/plastics/basic materials': 0,
#   'SECTOR_IT Services': 0,
#   'SECTOR_Electrical Equipment': 0,
#   'SECTOR_Real Estate Management & Development': 0,
#   'SECTOR_Health Care Equipment & Supplies': 0,
#   'SECTOR_Electric Utilities': 0,
#   'SECTOR_Apparel & textile': 0,
#   'SECTOR_Diversified Financial Services': 0,
#   'SECTOR_Machinery': 0,
#   'SECTOR_Finance': 0,
#   'SECTOR_Health Care Technology': 0,
#   'SECTOR_Biotechnology': 0,
#   'SECTOR_Household Durables': 0,
#   'SECTOR_Diversified Telecommunication Services': 0,
#   'SECTOR_Semiconductors & Semiconductor Equipment': 0,
#   'SECTOR_Media': 0,
#   'SECTOR_Software': 0,
#   'SECTOR_Multi-Utilities': 0,
#   'SECTOR_Banks': 0,
#   'SECTOR_Chemicals': 0,
#   'SECTOR_Natural resources': 0,
#   'SECTOR_Communications Equipment': 0,
#   'SECTOR_Internet & Direct Marketing Retail': 0,
#   'SECTOR_Textiles, Apparel & Luxury Goods': 0,
#   'SECTOR_Leisure Products': 0,
#   'SECTOR_Commercial Services & Supplies': 0,
#   'SECTOR_Consumer Finance': 0,
#   'SECTOR_Health Sector': 0,
#   'SECTOR_Energy': 0,
#   'SECTOR_Technology': 1,
#   'SECTOR_Leisure': 0,
#   'SECTOR_Airlines': 0,
#   'SECTOR_Furnishings': 0,
#   'SECTOR_Health Care Providers & Services': 0,
#   'SECTOR_Electronic Equipment, Instruments & Components': 0,
#   'SECTOR_Distributors': 0,
#   'SECTOR_Travel': 0,
#   'SECTOR_Chemical': 0,
#   'SECTOR_Military/weapons/security equipment': 0,
#   'SECTOR_Sports': 0,
#   'SECTOR_Energy Equipment & Services': 0,
#   'SECTOR_Media/publishing': 0,
#   'SECTOR_Internet Software & Services': 0,
#   'SECTOR_Oil, Gas & Consumable Fuels': 0,
#   'SECTOR_Building Products': 0,
#   'SECTOR_Utilities': 0,
#   'SECTOR_Water Utilities': 0,
#   'SECTOR_Metals & Mining': 0,
#   'SECTOR_Food Products': 0,
#   'SECTOR_Wireless Telecommunication Services': 0,
#   'SECTOR_Conglomerates': 0,
#   'SECTOR_Tobacco': 0,
#   'SECTOR_Auto Components': 0,
#   'SECTOR_Food & Staples Retailing': 0,
#   'SECTOR_Multiline Retail': 0,
#   'SECTOR_Trading Companies & Distributors': 0,
#   'SECTOR_Transportation Infrastructure': 0,
#   'SECTOR_Personal Products': 0,
#   'SECTOR_Marine': 0,
#   'SECTOR_Transport': 0,
#   'SECTOR_Hotels, Restaurants & Leisure': 0,
#   'SECTOR_Professional Services': 0,
#   'SECTOR_Containers & Packaging': 0,
#   'SECTOR_Real estate': 0,
#   'SECTOR_Services': 0,
#   'SECTOR_Manufacturing': 0,
#   'SECTOR_Technology Hardware, Storage & Peripherals': 0,
#   'SECTOR_Agriculture/food/beverage/tobacco/fishing': 0,
#   'SECTOR_Paper & Forest Products': 0,
#   'SECTOR_Automobiles': 0,
#   'SECTOR_Industrial Conglomerates': 0,
#   'SECTOR_Aerospace & Defense': 0,
#   'SECTOR_Specialty Retail': 0,
#   'SECTOR_Pharmaceuticals': 0}]

# %%
# Fixing subsectors
distinct_subsectors = set()
for k, list_dict in tqdm(json_obj.items(), leave=False, position=0):
    for dict_ in list_dict:
        for subsectors in dict_["sectors"].values():
            for subsector in subsectors:
                distinct_subsectors.add(subsector)
                
for k, list_dict in tqdm(json_obj_flat.items(), leave=False, position=0):
    new_list_dict = []
    for dict_ in list_dict:
        new_dict_ = deepcopy(dict_)
        
        for subsector in distinct_subsectors:
            new_dict_[f"SUBSECTOR_{subsector}"] = 0
        
        for subsectors in dict_["sectors"].values():
            for subsector in subsectors:
                new_dict_[f"SUBSECTOR_{subsector}"] = 1
                
        new_list_dict.append(new_dict_)
    json_obj_flat[k] = new_list_dict

# %%
json_obj_flat[list(json_obj_flat.keys())[0]]
# Out:
# [{'final_statement': '1Spatial Modern Slavery Act Policy Statement Home Solutions Solutions Government Boundaries Law Enforcement Rural Payments Next Generation 911 Utilities ArcGIS Utility Network Accelerator Traffic Management Plan Automation (TMPA) Automated Schematics Pipe Inference Incident Management Leakage Solutions Transport and Infrastructure Supply Chain Data Quality Highway Performance Monitoring System Next Generation 911 Services Consultancy Support Training 1Spatial Training FME Training Geocortex Training "1Spatial provides excellent knowledge and support to meet our current business needs. Individuals also go the extra mile in responding to critical issues and timescales, which is always very much appreciated and essential to the continued success of our business." Danny O\'Reilly | DAERA Industries Industries Utilities Water and Wastewater Gas Electricity Telecommunications Government National Mapping Agencies Land and Environmental Management Public Sector Procurement Industries Transportation and Infrastructure Rail Roads and Highways Aeronautical Ports Maritime and Hydrographic Defence Engineering Facilities Management Services Consultancy Support Training 1Spatial Training FME Training Geocortex Training "1Spatial have helped us to find innovative solutions to some of our long-standing business problems that have then been delivered quickly and efficiently." Paul Williams | United Utilities Products Products 1Integrate 1Data Gateway 1Integrate for ArcGIS 1Edit 1Generalise 1Spatial Management Suite Location Master Data Management Location Mobile App Platform (LMAP) Elyx Suite Products FME FME Desktop FME Server FME Cloud FME Maintenance FME Tools Geocortex Services Consultancy Support Training 1Spatial Training FME Training Geocortex Training "The feedback we’ve had from the business – from management and from engineers on the ground – has been amazing, really positive. We achieved a huge amount in a very, very short space of time." Alex Hincks, Senior Project Manager | Environment Agency Clients About Us About Us Careers Location Master Data Management Our Rules-Based Approach Partners Affiliations Corporate Social Responsibility Legal Anti-Bribery Policy Statement Environmental Policy Equality & Diversity Policy Statement Health and Safety Policy Statement Modern Slavery Act Policy Statement Public Interest Disclosure (Whistleblowing) Policy Statement News Events Events Events On-Demand Webinars Investors Investors Advisors AIM 26 Rule Annual and Interim Reports Board Company Announcements Corporate Governance Shareholders Shareholder Communications Shareprice Strategy Investor Enquiries Independent Research – Edison Investments Select region UK France USA Australia Belgium Careers Contact us Home Solutions Industries Products Clients About Us News Events Investors Home Solutions Solutions Government Boundaries Law Enforcement Rural Payments Next Generation 911 Utilities ArcGIS Utility Network Accelerator Traffic Management Plan Automation (TMPA) Automated Schematics Pipe Inference Incident Management Leakage Solutions Transport and Infrastructure Supply Chain Data Quality Highway Performance Monitoring System Next Generation 911 Services Consultancy Support Training 1Spatial Training FME Training Geocortex Training "1Spatial provides excellent knowledge and support to meet our current business needs. Individuals also go the extra mile in responding to critical issues and timescales, which is always very much appreciated and essential to the continued success of our business." Danny O\'Reilly | DAERA Industries Industries Utilities Water and Wastewater Gas Electricity Telecommunications Government National Mapping Agencies Land and Environmental Management Public Sector Procurement Industries Transportation and Infrastructure Rail Roads and Highways Aeronautical Ports Maritime and Hydrographic Defence Engineering Facilities Management Services Consultancy Support Training 1Spatial Training FME Training G ...
#   'Company': '1Spatial Plc',
#   'FS_industry': 'Software',
#   'FS_hq': 'United Kingdom',
#   'FS_uk_modern_slavery_act': True,
#   'FS_california_transparency_in_supply_chains_act': False,
#   'FS_australia_modern_slavery_act': False,
#   'FS_period_covered': '2017',
#   'year': None,
#   'sectors': {'Technology': ['General']},
#   'HQ_Luxembourg': 0,
#   'HQ_KZ': 0,
#   'HQ_RU': 0,
#   'HQ_Spain': 0,
#   'HQ_CY': 0,
#   'HQ_US': 0,
#   'HQ_GG': 0,
#   'HQ_Taiwan': 0,
#   'HQ_KR': 0,
#   'HQ_BE': 0,
#   'HQ_VN': 0,
#   'HQ_GB': 1,
#   'HQ_LU': 0,
#   'HQ_United Arab Emirates': 0,
#   'HQ_SA': 0,
#   'HQ_HN': 0,
#   'HQ_Australia': 0,
#   'HQ_CH': 0,
#   'HQ_ZA': 0,
#   'HQ_CA': 0,
#   'HQ_QA': 0,
#   'HQ_OM': 0,
#   'HQ_NZ': 0,
#   'HQ_Finland': 0,
#   'HQ_AF': 0,
#   'HQ_IL': 0,
#   'HQ_IT': 0,
#   'HQ_SG': 0,
#   'HQ_AE': 0,
#   'HQ_TH': 0,
#   'HQ_JP': 0,
#   'HQ_NL': 0,
#   'HQ_DE': 0,
#   'HQ_Canada': 0,
#   'HQ_GL': 0,
#   'HQ_AT': 0,
#   'HQ_Ireland': 0,
#   'HQ_TW': 0,
#   'HQ_ES': 0,
#   'HQ_MY': 0,
#   'HQ_KW': 0,
#   'HQ_CN': 0,
#   'HQ_Sweden': 0,
#   'HQ_Japan': 0,
#   'HQ_FI': 0,
#   'HQ_Austria': 0,
#   'HQ_None': 0,
#   'HQ_NO': 0,
#   'HQ_PH': 0,
#   'HQ_Hong Kong': 0,
#   'HQ_AU': 0,
#   'HQ_BM': 0,
#   'HQ_MX': 0,
#   'HQ_Germany': 0,
#   'HQ_BR': 0,
#   'HQ_GE': 0,
#   'HQ_United Kingdom': 0,
#   'HQ_CL': 0,
#   'HQ_Netherlands': 0,
#   'HQ_PL': 0,
#   'HQ_United States': 0,
#   'HQ_India': 0,
#   'HQ_IE': 0,
#   'HQ_HK': 0,
#   'HQ_UG': 0,
#   'HQ_TR': 0,
#   'HQ_FR': 0,
#   'HQ_Belgium': 0,
#   'HQ_DK': 0,
#   'HQ_SE': 0,
#   'HQ_IN': 0,
#   'HQ_IO': 0,
#   'HQ_JE': 0,
#   'HQ_BH': 0,
#   'SECTOR_Charity/Non-Profit': 0,
#   'SECTOR_Shipping & handling': 0,
#   'SECTOR_Household Products': 0,
#   'SECTOR_Other': 0,
#   'SECTOR_Insurance': 0,
#   'SECTOR_Construction & Engineering': 0,
#   'SECTOR_Air Freight & Logistics': 0,
#   'SECTOR_Safety/environment': 0,
#   'SECTOR_Public Entities': 0,
#   'SECTOR_Garden/landscaping': 0,
#   'SECTOR_Equity Real Estate Investment Trusts (REITs)': 0,
#   'SECTOR_Road & Rail': 0,
#   'SECTOR_Consumer products/retail': 0,
#   'SECTOR_Beverages': 0,
#   'SECTOR_Independent Power and Renewable Electricity Producers': 0,
#   'SECTOR_Construction Materials': 0,
#   'SECTOR_Diversified Consumer Services': 0,
#   'SECTOR_Thrifts & Mortgage Finance': 0,
#   'SECTOR_Construction & building materials': 0,
#   'SECTOR_Capital Markets': 0,
#   'SECTOR_Metals/plastics/basic materials': 0,
#   'SECTOR_IT Services': 0,
#   'SECTOR_Electrical Equipment': 0,
#   'SECTOR_Real Estate Management & Development': 0,
#   'SECTOR_Health Care Equipment & Supplies': 0,
#   'SECTOR_Electric Utilities': 0,
#   'SECTOR_Apparel & textile': 0,
#   'SECTOR_Diversified Financial Services': 0,
#   'SECTOR_Machinery': 0,
#   'SECTOR_Finance': 0,
#   'SECTOR_Health Care Technology': 0,
#   'SECTOR_Biotechnology': 0,
#   'SECTOR_Household Durables': 0,
#   'SECTOR_Diversified Telecommunication Services': 0,
#   'SECTOR_Semiconductors & Semiconductor Equipment': 0,
#   'SECTOR_Media': 0,
#   'SECTOR_Software': 0,
#   'SECTOR_Multi-Utilities': 0,
#   'SECTOR_Banks': 0,
#   'SECTOR_Chemicals': 0,
#   'SECTOR_Natural resources': 0,
#   'SECTOR_Communications Equipment': 0,
#   'SECTOR_Internet & Direct Marketing Retail': 0,
#   'SECTOR_Textiles, Apparel & Luxury Goods': 0,
#   'SECTOR_Leisure Products': 0,
#   'SECTOR_Commercial Services & Supplies': 0,
#   'SECTOR_Consumer Finance': 0,
#   'SECTOR_Health Sector': 0,
#   'SECTOR_Energy': 0,
#   'SECTOR_Technology': 1,
#   'SECTOR_Leisure': 0,
#   'SECTOR_Airlines': 0,
#   'SECTOR_Furnishings': 0,
#   'SECTOR_Health Care Providers & Services': 0,
#   'SECTOR_Electronic Equipment, Instruments & Components': 0,
#   'SECTOR_Distributors': 0,
#   'SECTOR_Travel': 0,
#   'SECTOR_Chemical': 0,
#   'SECTOR_Military/weapons/security equipment': 0,
#   'SECTOR_Sports': 0,
#   'SECTOR_Energy Equipment & Services': 0,
#   'SECTOR_Media/publishing': 0,
#   'SECTOR_Internet Software & Services': 0,
#   'SECTOR_Oil, Gas & Consumable Fuels': 0,
#   'SECTOR_Building Products': 0,
#   'SECTOR_Utilities': 0,
#   'SECTOR_Water Utilities': 0,
#   'SECTOR_Metals & Mining': 0,
#   'SECTOR_Food Products': 0,
#   'SECTOR_Wireless Telecommunication Services': 0,
#   'SECTOR_Conglomerates': 0,
#   'SECTOR_Tobacco': 0,
#   'SECTOR_Auto Components': 0,
#   'SECTOR_Food & Staples Retailing': 0,
#   'SECTOR_Multiline Retail': 0,
#   'SECTOR_Trading Companies & Distributors': 0,
#   'SECTOR_Transportation Infrastructure': 0,
#   'SECTOR_Personal Products': 0,
#   'SECTOR_Marine': 0,
#   'SECTOR_Transport': 0,
#   'SECTOR_Hotels, Restaurants & Leisure': 0,
#   'SECTOR_Professional Services': 0,
#   'SECTOR_Containers & Packaging': 0,
#   'SECTOR_Real estate': 0,
#   'SECTOR_Services': 0,
#   'SECTOR_Manufacturing': 0,
#   'SECTOR_Technology Hardware, Storage & Peripherals': 0,
#   'SECTOR_Agriculture/food/beverage/tobacco/fishing': 0,
#   'SECTOR_Paper & Forest Products': 0,
#   'SECTOR_Automobiles': 0,
#   'SECTOR_Industrial Conglomerates': 0,
#   'SECTOR_Aerospace & Defense': 0,
#   'SECTOR_Specialty Retail': 0,
#   'SECTOR_Pharmaceuticals': 0,
#   'SUBSECTOR_Auto rental': 0,
#   'SUBSECTOR_Sporting goods': 0,
#   'SUBSECTOR_Charity/Non-Profit': 0,
#   'SUBSECTOR_Medical equipment/supplies': 0,
#   'SUBSECTOR_Construction': 0,
#   'SUBSECTOR_Jewellery': 0,
#   'SUBSECTOR_Auto parts': 0,
#   'SUBSECTOR_Fertiliser': 0,
#   'SUBSECTOR_Insurance': 0,
#   'SUBSECTOR_Wholesale': 0,
#   'SUBSECTOR_Public Entities': 0,
#   'SUBSECTOR_Gardening & landscaping': 0,
#   'SUBSECTOR_Environmental equipment': 0,
#   'SUBSECTOR_Metals & steel': 0,
#   'SUBSECTOR_Paper & cardboard': 0,
#   'SUBSECTOR_Internet & social media': 0,
#   'SUBSECTOR_Software & Services': 0,
#   'SUBSECTOR_Footwear': 0,
#   'SUBSECTOR_Waste disposal': 0,
#   'SUBSECTOR_Advertising & marketing': 0,
#   'SUBSECTOR_Machine & machine tools': 0,
#   'SUBSECTOR_Perfume': 0,
#   'SUBSECTOR_Restaurants & bars': 0,
#   'SUBSECTOR_Leather & tanneries': 0,
#   'SUBSECTOR_Ferry': 0,
#   'SUBSECTOR_Bicycle': 0,
#   'SUBSECTOR_Household products': 0,
#   'SUBSECTOR_Nuclear energy': 0,
#   'SUBSECTOR_Health care': 0,
#   'SUBSECTOR_Engineering': 0,
#   'SUBSECTOR_Airports': 0,
#   'SUBSECTOR_Call centre': 0,
#   'SUBSECTOR_Fishing': 0,
#   'SUBSECTOR_Tea': 0,
#   'SUBSECTOR_Tire': 0,
#   'SUBSECTOR_Hydropower & dam projects': 0,
#   'SUBSECTOR_Tourism': 0,
#   'SUBSECTOR_Retail': 0,
#   'SUBSECTOR_Stock exchanges': 0,
#   'SUBSECTOR_Cruise ship': 0,
#   'SUBSECTOR_Electrical appliance': 0,
#   'SUBSECTOR_Cement': 0,
#   'SUBSECTOR_Department stores': 0,
#   'SUBSECTOR_Biotechnology': 0,
#   'SUBSECTOR_Diamond': 0,
#   'SUBSECTOR_Security companies': 0,
#   'SUBSECTOR_Water companies': 0,
#   'SUBSECTOR_Luggage, backpacks & bags': 0,
#   'SUBSECTOR_Arms/Weapons': 0,
#   'SUBSECTOR_Automobile & other motor vehicles': 0,
#   'SUBSECTOR_Finance & banking': 0,
#   'SUBSECTOR_Construction machinery & vehicles': 0,
#   'SUBSECTOR_Property management': 0,
#   'SUBSECTOR_Building materials & equipment': 0,
#   'SUBSECTOR_Real estate sales': 0,
#   'SUBSECTOR_Energy': 0,
#   'SUBSECTOR_Golf courses': 0,
#   'SUBSECTOR_Express delivery': 0,
#   'SUBSECTOR_Renewable Energy': 0,
#   'SUBSECTOR_Toiletries & soap': 0,
#   'SUBSECTOR_Solar energy': 0,
#   'SUBSECTOR_Toy': 0,
#   'SUBSECTOR_Media & publishing: General': 0,
#   'SUBSECTOR_Architects': 0,
#   'SUBSECTOR_Ports': 0,
#   'SUBSECTOR_Recruitment agencies': 0,
#   'SUBSECTOR_Postal services': 0,
#   'SUBSECTOR_Chocolate & cocoa': 0,
#   'SUBSECTOR_Agriculture & livestock': 0,
#   'SUBSECTOR_Agricultural machinery': 0,
#   'SUBSECTOR_Coffee': 0,
#   'SUBSECTOR_Diversified/Conglomerates': 0,
#   'SUBSECTOR_Wind energy': 0,
#   'SUBSECTOR_Pesticide': 0,
#   'SUBSECTOR_Military/defence': 0,
#   'SUBSECTOR_Office equipment': 0,
#   'SUBSECTOR_Shipping, ship-building & ship-scrapping': 0,
#   'SUBSECTOR_Tobacco': 0,
#   'SUBSECTOR_Technology, telecom & electronics': 0,
#   'SUBSECTOR_Printing & copying': 0,
#   'SUBSECTOR_Sports teams, clubs & leagues': 0,
#   'SUBSECTOR_Property development': 0,
#   'SUBSECTOR_General': 1,
#   'SUBSECTOR_Supermarkets & grocery': 0,
#   'SUBSECTOR_Bus': 0,
#   'SUBSECTOR_Cosmetics': 0,
#   'SUBSECTOR_Auditing, consulting & accounting': 0,
#   'SUBSECTOR_Food & beverage': 0,
#   'SUBSECTOR_Watch & clock': 0,
#   'SUBSECTOR_Mining': 0,
#   'SUBSECTOR_Furniture': 0,
#   'SUBSECTOR_Photographic': 0,
#   'SUBSECTOR_Freight handling': 0,
#   'SUBSECTOR_Law firms': 0,
#   'SUBSECTOR_Hotel': 0,
#   'SUBSECTOR_Logging & lumber': 0,
#   'SUBSECTOR_Pharmaceutical': 0,
#   'SUBSECTOR_Cleaning & maintenance': 0,
#   'SUBSECTOR_Aircraft/Airline': 0,
#   'SUBSECTOR_Education companies': 0,
#   'SUBSECTOR_Entertainment': 0,
#   'SUBSECTOR_Gambling': 0,
#   'SUBSECTOR_Packaging': 0,
#   'SUBSECTOR_Clothing & textile': 0,
#   'SUBSECTOR_Oil, gas & coal': 0,
#   'SUBSECTOR_Catering & food services': 0,
#   'SUBSECTOR_Industrial gases': 0}]

# %%
# final flattening operation
final_json_obj_flat = []
for k, v1 in tqdm(json_obj_flat.items(), leave=False, position=0):
    new_flat_list = []
    for v2 in v1:
        new_dict_ = deepcopy(v2)
        del new_dict_["sectors"]
        new_dict_["statement"] = k
        new_flat_list.append(new_dict_)
    final_json_obj_flat += new_flat_list

# %%
final_flat_df = pd.DataFrame.from_dict(final_json_obj_flat)

same_hqs = {
    "ES": "Spain", 
    "LU": "Luxembourg", 
    "NL": "Netherlands",
    "HK": "Hong Kong",
    "CA": "Canada",
    "TW": "Taiwan", 
    "SE": "Sweden", 
    "AE": "United Arab Emirates", 
    "US": "United States",
    "JP": "Japan", 
    "GB": "United Kingdom",
    "FI": "Finland", 
    "AU": "Australia",
    "DE": "Germany",
    "IE": "Ireland", 
    "AT": "Austria",
    "BE": "Belgium", 
    "IN": "India"}
for hq1, hq2 in same_hqs.items():
    final_flat_df[f"HQ_{hq1}"] = np.where((final_flat_df[f"HQ_{hq1}"]==1) | (final_flat_df[f"HQ_{hq2}"]==1),1,0)
    final_flat_df.drop(f"HQ_{hq2}", inplace=True, axis=1)

# %%
print(*final_flat_df.columns, sep=", ")
# Out:
# final_statement, Company, FS_industry, FS_hq, FS_uk_modern_slavery_act, FS_california_transparency_in_supply_chains_act, FS_australia_modern_slavery_act, FS_period_covered, year, HQ_KZ, HQ_RU, HQ_CY, HQ_US, HQ_GG, HQ_KR, HQ_BE, HQ_VN, HQ_GB, HQ_LU, HQ_SA, HQ_HN, HQ_CH, HQ_ZA, HQ_CA, HQ_QA, HQ_OM, HQ_NZ, HQ_AF, HQ_IL, HQ_IT, HQ_SG, HQ_AE, HQ_TH, HQ_JP, HQ_NL, HQ_DE, HQ_GL, HQ_AT, HQ_TW, HQ_ES, HQ_MY, HQ_KW, HQ_CN, HQ_FI, HQ_None, HQ_NO, HQ_PH, HQ_AU, HQ_BM, HQ_MX, HQ_BR, HQ_GE, HQ_CL, HQ_PL, HQ_IE, HQ_HK, HQ_UG, HQ_TR, HQ_FR, HQ_DK, HQ_SE, HQ_IN, HQ_IO, HQ_JE, HQ_BH, SECTOR_Charity/Non-Profit, SECTOR_Shipping & handling, SECTOR_Household Products, SECTOR_Other, SECTOR_Insurance, SECTOR_Construction & Engineering, SECTOR_Air Freight & Logistics, SECTOR_Safety/environment, SECTOR_Public Entities, SECTOR_Garden/landscaping, SECTOR_Equity Real Estate Investment Trusts (REITs), SECTOR_Road & Rail, SECTOR_Consumer products/retail, SECTOR_Beverages, SECTOR_Independent Power and Renewable Electricity Producers, SECTOR_Construction Materials, SECTOR_Diversified Consumer Services, SECTOR_Thrifts & Mortgage Finance, SECTOR_Construction & building materials, SECTOR_Capital Markets, SECTOR_Metals/plastics/basic materials, SECTOR_IT Services, SECTOR_Electrical Equipment, SECTOR_Real Estate Management & Development, SECTOR_Health Care Equipment & Supplies, SECTOR_Electric Utilities, SECTOR_Apparel & textile, SECTOR_Diversified Financial Services, SECTOR_Machinery, SECTOR_Finance, SECTOR_Health Care Technology, SECTOR_Biotechnology, SECTOR_Household Durables, SECTOR_Diversified Telecommunication Services, SECTOR_Semiconductors & Semiconductor Equipment, SECTOR_Media, SECTOR_Software, SECTOR_Multi-Utilities, SECTOR_Banks, SECTOR_Chemicals, SECTOR_Natural resources, SECTOR_Communications Equipment, SECTOR_Internet & Direct Marketing Retail, SECTOR_Textiles, Apparel & Luxury Goods, SECTOR_Leisure Products, SECTOR_Commercial Services & Supplies, SECTOR_Consumer Finance, SECTOR_Health Sector, SECTOR_Energy, SECTOR_Technology, SECTOR_Leisure, SECTOR_Airlines, SECTOR_Furnishings, SECTOR_Health Care Providers & Services, SECTOR_Electronic Equipment, Instruments & Components, SECTOR_Distributors, SECTOR_Travel, SECTOR_Chemical, SECTOR_Military/weapons/security equipment, SECTOR_Sports, SECTOR_Energy Equipment & Services, SECTOR_Media/publishing, SECTOR_Internet Software & Services, SECTOR_Oil, Gas & Consumable Fuels, SECTOR_Building Products, SECTOR_Utilities, SECTOR_Water Utilities, SECTOR_Metals & Mining, SECTOR_Food Products, SECTOR_Wireless Telecommunication Services, SECTOR_Conglomerates, SECTOR_Tobacco, SECTOR_Auto Components, SECTOR_Food & Staples Retailing, SECTOR_Multiline Retail, SECTOR_Trading Companies & Distributors, SECTOR_Transportation Infrastructure, SECTOR_Personal Products, SECTOR_Marine, SECTOR_Transport, SECTOR_Hotels, Restaurants & Leisure, SECTOR_Professional Services, SECTOR_Containers & Packaging, SECTOR_Real estate, SECTOR_Services, SECTOR_Manufacturing, SECTOR_Technology Hardware, Storage & Peripherals, SECTOR_Agriculture/food/beverage/tobacco/fishing, SECTOR_Paper & Forest Products, SECTOR_Automobiles, SECTOR_Industrial Conglomerates, SECTOR_Aerospace & Defense, SECTOR_Specialty Retail, SECTOR_Pharmaceuticals, SUBSECTOR_Auto rental, SUBSECTOR_Sporting goods, SUBSECTOR_Charity/Non-Profit, SUBSECTOR_Medical equipment/supplies, SUBSECTOR_Construction, SUBSECTOR_Jewellery, SUBSECTOR_Auto parts, SUBSECTOR_Fertiliser, SUBSECTOR_Insurance, SUBSECTOR_Wholesale, SUBSECTOR_Public Entities, SUBSECTOR_Gardening & landscaping, SUBSECTOR_Environmental equipment, SUBSECTOR_Metals & steel, SUBSECTOR_Paper & cardboard, SUBSECTOR_Internet & social media, SUBSECTOR_Software & Services, SUBSECTOR_Footwear, SUBSECTOR_Waste disposal, SUBSECTOR_Advertising & marketing, SUBSECTOR_Machine & machine tools, SUBSECTOR_Perfume, SUBSECTOR_Restaurants & bars, SUBSECTOR_Leather & tanneries, SUBSECTOR_Ferry, SUBSECTOR_Bicycle, SUBSECTOR_Household products,  ...

# %%
final_flat_df.fillna(value="#NA", inplace=True)

# %%
final_flat_df.to_excel(os.path.join(SHEETS_PATH, "subset_data_v4.xlsx"), index=False)

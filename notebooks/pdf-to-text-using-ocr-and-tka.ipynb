# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Import libraries 
from PIL import Image 
import pytesseract 
import re
from pdf2image import convert_from_path 
from os import getcwd, remove, path
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract'

from tika import parser
import glob
import pickle
import pandas as pd

# %%
PROJECT_NAME = 'modern_slavery_registry'
PROJECT_PATH = f"{getcwd()[:getcwd().find(PROJECT_NAME)]}{PROJECT_NAME}"
DATA_PATH = f"{PROJECT_PATH}\\data"
PICKLE_PATH = f"{DATA_PATH}\\pickles"
PDF_PATH = f"{DATA_PATH}\\pdfs"
TEXT_PATH = f"{DATA_PATH}\\texts"
SLAVERY_TEXT_PATH = f"{DATA_PATH}\\slavery_texts"
MAX_DOWNLOAD_TIME = 5

# %%
def save_pickle(obj, file_name):
    pickle.dump(obj, file=open(f"{file_name}.pickle","wb"))
    
def load_pickle(file_name):
    return pickle.load(file=open(f"{file_name}.pickle","rb"))

# %%
pdfs = glob.glob(pathname=f"{PDF_PATH}\\*.pdf")
TOTAL_PDFs = len(pdfs)
print(f"Found {TOTAL_PDFs} pdfs.")
# Out:
# Found 15068 pdfs.

# %%
df = pd.read_csv(f"{DATA_PATH}\modernslaveryregistry-2020-09-14.csv")
df.head()
# Out:
#    Company ID                              Company  Is Publisher  \
# 0        7676      "K" Line Holding Europe Limited          True
# 1       28660  "K" Line Bulk Shipping (UK) Limited         False
# 2       28659            "K" Line (Europe) Limited         False
# 3       28661        "K" Line LNG Shipping Limited         False
# 4       28658      Polar LNG Shipping (UK) Limited         False
#
#    Statement ID                                                URL  \
# 0         35092  https://img1.wsimg.com/blobby/go/7695baff-3f0f...
# 1         35092  https://img1.wsimg.com/blobby/go/7695baff-3f0f...
# 2         35092  https://img1.wsimg.com/blobby/go/7695baff-3f0f...
# 3         35092  https://img1.wsimg.com/blobby/go/7695baff-3f0f...
# 4         35092  https://img1.wsimg.com/blobby/go/7695baff-3f0f...
#
#   Override URL Companies House Number Industry              HQ  \
# 0          NaN               05005018   Marine  United Kingdom
# 1          NaN               04830352   Marine  United Kingdom
# 2          NaN               05639474   Marine  United Kingdom
# 3          NaN                    NaN   Marine  United Kingdom
# 4          NaN               02205323   Marine  United Kingdom
#
#    Is Also Covered  UK Modern Slavery Act  \
# 0            False                   True
# 1             True                   True
# 2             True                   True
# 3             True                   True
# 4             True                   True
#
#    California Transparency in Supply Chains Act  Australia Modern Slavery Act  \
# 0                                         False                         False
# 1                                         False                         False
# 2                                         False                         False
# 3                                         False                         False
# 4                                         False                         False
#
#   Period Covered
# 0      2018-2019
# 1      2018-2019
# 2      2018-2019
# 3      2018-2019
# 4      2018-2019

# %%
def get_pdf_url_from_sid(sid):
    """Returns PDF url for input sid."""
    return df[df['Statement ID']==sid]['URL'].values[0]

# %%
def get_sid_from_filename(file_name):
    """Extract and return SID from file_name."""
    return int(re.findall(pattern=r"[\d]+",string=path.basename(file_name))[0])

# %%
def extract_text_from_pdf_using_tika(pdf_name):
    """Return PDF content using Tika."""
    return parser.from_file(pdf_name)['content']

# %%
def extract_text_from_pdf_using_ocr(pdf_file_name):
    """Extract and return from PDF."""
    sid = get_sid_from_filename(pdf_file_name)
    pages = convert_from_path(pdf_path=pdf_file_name, dpi=500) 
    text = ""
    for i, page in enumerate(pages):
        image_name = f"{sid}-{i}.jpg"
        page.save(image_name, "JPEG")
        text = text + " " + str(pytesseract.image_to_string(Image.open(image_name)))
        remove(image_name)
    return text

# %%
def print_loop_no(total_sids, sid, itr, type_, type_itr, msg=""):
    """Print loop statements."""
    primary_text = f"Running - {itr}/{total_sids} , SID - {sid}"
    if type_ == "Success":
        primary_text = f"{primary_text} - Success - {type_itr}"
    elif type_ == "Failed":
        primary_text = f"{primary_text} - Failed - {type_itr}"
    else:
        primary_text = f"{primary_text} - Processed - {type_itr}"
    print(f"{'-'*8} {primary_text} - {msg} - {'-'*8}")

# %%
def clean_text(text):
    """Clean and return input text."""
    text = text.replace("\n", " ")
    text = text.replace("\t", " ")
    return " ".join(text.split())

# %%
def save_text(text, sid):
    """Save text in text file."""
    file_name = f"SID-{sid}" 
    file_obj = open(f"{TEXT_PATH}//{file_name}.txt", 'w', encoding='utf-8')
    file_obj.write(text)
    file_obj.close()

# %%
pickle_name = "leftover_pdf_to_downloads_SIDs"
leftover_SIDs = load_pickle(file_name=f"{PICKLE_PATH}\\{pickle_name}")
TOTAL_SIDs = len(leftover_SIDs)
print(f"Total SIDs - PDFs left to download : {len(leftover_SIDs)}")

# %%
PDF_SIDs = [get_sid_from_filename(pdf_file_name) for pdf_file_name in pdfs]
PDF_SIDs = [sid for sid in leftover_SIDs if sid in PDF_SIDs]

# %%
TOTAL_SIDs = len(PDF_SIDs)
print(f"Total text extraction required from : {TOTAL_SIDs} pdfs")

# %%
extracted_text_SIDs = []
failed_text_SIDs = []

# %%
# pdf_name = f"{PDF_PATH}\\SID-{8745}.pdf"
# text = extract_text_from_pdf_using_tika(pdf_name)
# if not text:
#     text = extract_text_from_pdf_using_ocr(pdf_name)
# text = clean_text(text)     
# text

# %%
for i, sid in enumerate(PDF_SIDs):
    pdf_name = f"{PDF_PATH}\\SID-{sid}.pdf"
    try:
        text = extract_text_from_pdf_using_tika(pdf_name)
        if not text:
            text = extract_text_from_pdf_using_ocr(pdf_name)
        text = clean_text(text)     
        save_text(text=text, sid=sid)
        extracted_text_SIDs.append(int(sid))
        print_loop_no(total_sids=TOTAL_SIDs,
                      sid=sid, 
                      itr=i+1, 
                      type_="Success",
                      type_itr=len(extracted_text_SIDs))
    except:
        failed_text_SIDs.append(int(sid))
        print_loop_no(total_sids=TOTAL_SIDs,
                      sid=sid, 
                      itr=i+1, 
                      type_="Failed",
                      type_itr=len(failed_text_SIDs))

# %% [markdown]
# # Running extracting texts from small text file for which text was not extracted properly

# %%
small_text_files = glob.glob(f"{SLAVERY_TEXT_PATH}//*.txt")
small_text_files = [file for file in small_text_files if path.getsize(file) < 1000]
print(f"Found {len(small_text_files)} small text files.")
small_text_SIDs = [get_sid_from_filename(file) for file in small_text_files]
# Out:
# Found 273 small text files.

# %%
for i, sid in enumerate(small_text_SIDs):
    pdf_name = f"{PDF_PATH}\\SID-{sid}.pdf"
    try:
        text = extract_text_from_pdf_using_ocr(pdf_name)
        text = clean_text(text)     
        save_text(text=text, sid=sid)
        extracted_text_SIDs.append(int(sid))
        print_loop_no(total_sids=len(small_text_SIDs),
                      sid=sid, 
                      itr=i+1, 
                      type_="Success",
                      type_itr=len(extracted_text_SIDs), 
                      msg="OCR")
    except:
        try:
            text = extract_text_from_pdf_using_tika(pdf_name)
            text = clean_text(text)     
            save_text(text=text, sid=sid)
            extracted_text_SIDs.append(int(sid))
            print_loop_no(total_sids=len(small_text_SIDs),
                          sid=sid, 
                          itr=i+1, 
                          type_="Success",
                          type_itr=len(extracted_text_SIDs), 
                          msg="TIKA")
        except:
            failed_text_SIDs.append(int(sid))
            print_loop_no(total_sids=len(small_text_SIDs),
                          sid=sid, 
                          itr=i+1, 
                          type_="Failed",
                          type_itr=len(failed_text_SIDs))
# Out:
# -------- Running - 1/273 , SID - 10090 - Success - 1 - TIKA - --------
# -------- Running - 2/273 , SID - 10095 - Success - 2 - TIKA - --------
# -------- Running - 3/273 , SID - 10109 - Success - 3 - TIKA - --------
# -------- Running - 4/273 , SID - 10124 - Success - 4 - TIKA - --------
# -------- Running - 5/273 , SID - 10254 - Success - 5 - OCR - --------
# -------- Running - 6/273 , SID - 10426 - Success - 6 - TIKA - --------
# -------- Running - 7/273 , SID - 10510 - Success - 7 - TIKA - --------
# -------- Running - 8/273 , SID - 10514 - Success - 8 - TIKA - --------
# -------- Running - 9/273 , SID - 10529 - Success - 9 - TIKA - --------
# -------- Running - 10/273 , SID - 10611 - Success - 10 - TIKA - --------
# -------- Running - 11/273 , SID - 10667 - Success - 11 - OCR - --------
# -------- Running - 12/273 , SID - 10726 - Success - 12 - TIKA - --------
# -------- Running - 13/273 , SID - 10799 - Success - 13 - OCR - --------
# -------- Running - 14/273 , SID - 10892 - Success - 14 - OCR - --------
# -------- Running - 15/273 , SID - 10899 - Success - 15 - TIKA - --------
# -------- Running - 16/273 , SID - 10920 - Success - 16 - OCR - --------
# -------- Running - 17/273 , SID - 11027 - Success - 17 - OCR - --------
# -------- Running - 18/273 , SID - 11029 - Success - 18 - TIKA - --------
# -------- Running - 19/273 , SID - 11041 - Success - 19 - TIKA - --------
# -------- Running - 20/273 , SID - 11246 - Success - 20 - TIKA - --------
# -------- Running - 21/273 , SID - 11416 - Success - 21 - TIKA - --------
# -------- Running - 22/273 , SID - 11422 - Success - 22 - TIKA - --------
# -------- Running - 23/273 , SID - 11484 - Success - 23 - TIKA - --------
# -------- Running - 24/273 , SID - 11497 - Success - 24 - TIKA - --------
# -------- Running - 25/273 , SID - 11534 - Success - 25 - OCR - --------
# -------- Running - 26/273 , SID - 11558 - Success - 26 - OCR - --------
# -------- Running - 27/273 , SID - 11768 - Success - 27 - OCR - --------
# -------- Running - 28/273 , SID - 11818 - Success - 28 - OCR - --------
# -------- Running - 29/273 , SID - 11843 - Success - 29 - OCR - --------
# -------- Running - 30/273 , SID - 11938 - Success - 30 - OCR - --------
# -------- Running - 31/273 , SID - 12047 - Success - 31 - OCR - --------
# -------- Running - 32/273 , SID - 12186 - Success - 32 - TIKA - --------
# -------- Running - 33/273 , SID - 12219 - Success - 33 - TIKA - --------
# -------- Running - 34/273 , SID - 12293 - Success - 34 - TIKA - --------
# -------- Running - 35/273 , SID - 12329 - Success - 35 - OCR - --------
# -------- Running - 36/273 , SID - 12550 - Success - 36 - TIKA - --------
# -------- Running - 37/273 , SID - 12578 - Success - 37 - TIKA - --------
# -------- Running - 38/273 , SID - 12601 - Success - 38 - TIKA - --------
# -------- Running - 39/273 , SID - 12726 - Success - 39 - OCR - --------
# -------- Running - 40/273 , SID - 12739 - Success - 40 - OCR - --------
# -------- Running - 41/273 , SID - 12825 - Success - 41 - TIKA - --------
# -------- Running - 42/273 , SID - 12880 - Success - 42 - OCR - --------
# -------- Running - 43/273 , SID - 12896 - Success - 43 - TIKA - --------
# -------- Running - 44/273 , SID - 12968 - Success - 44 - TIKA - --------
# -------- Running - 45/273 , SID - 13074 - Success - 45 - OCR - --------
# -------- Running - 46/273 , SID - 24977 - Success - 46 - TIKA - --------
# -------- Running - 47/273 , SID - 25043 - Success - 47 - TIKA - --------
# -------- Running - 48/273 , SID - 25250 - Success - 48 - OCR - --------
# -------- Running - 49/273 , SID - 25260 - Success - 49 - OCR - --------
# -------- Running - 50/273 , SID - 25292 - Success - 50 - TIKA - --------
# -------- Running - 51/273 , SID - 25333 - Success - 51 - TIKA - --------
# -------- Running - 52/273 , SID - 25357 - Success - 52 - TIKA - --------
# -------- Running - 53/273 , SID - 25391 - Success - 53 - TIKA - --------
# -------- Running - 54/273 , SID - 25417 - Success - 54 - OCR - --------
# -------- Running - 55/273 , SID - 25420 - Success - 55 - OCR - --------
# -------- Running - 56/273 , SID - 25427 - Success - 56 - OCR - --------
# -------- Running - 57/273 , SID - 25516 - Success - 57 - TIKA - --------
# -------- Running - 58/273 , SID - 25572 - Success - 58 - TIKA - --------
# -------- Running - 59/273 , SID - 25615 - Success - 59 - OCR - --------
# -------- Running - 60/273 , SID - 25708 - Success - 60 - TIKA - --------
# -------- Running - 61/273 , SID - 25740 - Success - 61 - OCR - --------
# -------- Running - 62/273 , SID - 25788 - Success - 62 - OCR - --------
# -------- Running - 63/273 , SID - 25823 - Success - 63 - TIKA - --------
# -------- Running - 64/273 , SID - 25829 - Success - 64 - TIKA - --------
# -------- Running - 65/273 , SID - 25920 - Success - 65 - TIKA - --------
# -------- Running - 66/273 , SID - 26030 - Success - 66 - TIKA - --------
# -------- Running - 67/273 , SID - 26033 - Success - 67 - OCR - --------
# -------- Running - 68/273 , SID - 26048 - Success - 68 - TIKA - --------
# -------- Running - 69/273 , SID - 26077 - Success - 69 - TIKA - --------
# -------- Running - 70/273 , SID - 26433 - Success - 70 - TIKA - --------
# -------- Running - 71/273 , SID - 26464 - Success - 71 - TIKA - --------
# -------- Running - 72/273 , SID - 26626 - Success - 72 - OCR - --------
# -------- Running - 73/273 , SID - 26688 - Success - 73 - OCR - --------
# -------- Running - 74/273 , SID - 26746 - Success - 74 - OCR - --------
# -------- Running - 75/273 , SID - 27043 - Success - 75 - TIKA - --------
# -------- Running - 76/273 , SID - 27054 - Success - 76 - OCR - --------
# -------- Running - 77/273 , SID - 27055 - Success - 77 - TIKA - --------
# -------- Running - 78/273 , SID - 27121 - Success - 78 - TIKA - --------
# -------- Running - 79/273 , SID - 27238 - Success - 79 - TIKA - --------
# -------- Running - 80/273 , SID - 27333 - Success - 80 - OCR - --------
# -------- Running - 81/273 , SID - 27367 - Success - 81 - TIKA - --------
# -------- Running - 82/273 , SID - 27407 - Success - 82 - TIKA - --------
# -------- Running - 83/273 , SID - 27477 - Success - 83 - OCR - --------
# -------- Running - 84/273 , SID - 27484 - Success - 84 - TIKA - --------
# -------- Running - 85/273 , SID - 27775 - Success - 85 - TIKA - --------
# -------- Running - 86/273 , SID - 27894 - Success - 86 - TIKA - --------
# -------- Running - 87/273 , SID - 27895 - Success - 87 - TIKA - --------
# -------- Running - 88/273 , SID - 27896 - Success - 88 - TIKA - --------
# -------- Running - 89/273 , SID - 27897 - Success - 89 - TIKA - --------
# -------- Running - 90/273 , SID - 28050 - Success - 90 - OCR - --------
# -------- Running - 91/273 , SID - 28074 - Success - 91 - OCR - --------
# -------- Running - 92/273 , SID - 28240 - Success - 92 - OCR - --------
# -------- Running - 93/273 , SID - 28477 - Success - 93 - OCR - --------
# -------- Running - 94/273 , SID - 28515 - Success - 94 - TIKA - --------
# -------- Running - 95/273 , SID - 29373 - Success - 95 - OCR - --------
# -------- Running - 96/273 , SID - 29472 - Success - 96 - OCR - --------
# -------- Running - 97/273 , SID - 30432 - Success - 97 - TIKA - --------
# -------- Running - 98/273 , SID - 30445 - Success - 98 - TIKA - --------
# -------- Running - 99/273 , SID - 30505 - Success - 99 - TIKA - --------
# -------- Running - 100/273 , SID - 30506 - Success - 100 - TIKA - --------
# -------- Running - 101/273 , SID - 30779 - Success - 101 - TIKA - --------
# -------- Running - 102/273 , SID - 30901 - Success - 102 - OCR - --------
# -------- Running - 103/273 , SID - 30956 - Success - 103 - TIKA - --------
# -------- Running - 104/273 , SID - 31165 - Success - 104 - TIKA - --------
# -------- Running - 105/273 , SID - 31242 - Success - 105 - OCR - --------
# -------- Running - 106/273 , SID - 31283 - Success - 106 - TIKA - --------
# -------- Running - 107/273 , SID - 31313 - Success - 107 - TIKA - --------
# -------- Running - 108/273 , SID - 31497 - Success - 108 - OCR - --------
# -------- Running - 109/273 , SID - 31821 - Success - 109 - TIKA - --------
# -------- Running - 110/273 , SID - 31908 - Success - 110 - OCR - --------
# -------- Running - 111/273 , SID - 32119 - Success - 111 - OCR - --------
# -------- Running - 112/273 , SID - 32162 - Success - 112 - OCR - --------
# -------- Running - 113/273 , SID - 32200 - Success - 113 - TIKA - --------
# -------- Running - 114/273 , SID - 32341 - Success - 114 - TIKA - --------
# -------- Running - 115/273 , SID - 32345 - Success - 115 - TIKA - --------
# -------- Running - 116/273 , SID - 32485 - Success - 116 - OCR - --------
# -------- Running - 117/273 , SID - 32789 - Success - 117 - OCR - --------
# -------- Running - 118/273 , SID - 32895 - Success - 118 - TIKA - --------
# -------- Running - 119/273 , SID - 32898 - Success - 119 - OCR - --------
# -------- Running - 120/273 , SID - 32939 - Success - 120 - OCR - --------
# -------- Running - 121/273 , SID - 32940 - Success - 121 - OCR - --------
# -------- Running - 122/273 , SID - 32986 - Success - 122 - TIKA - --------
# -------- Running - 123/273 , SID - 33046 - Success - 123 - OCR - --------
# -------- Running - 124/273 , SID - 33062 - Success - 124 - OCR - --------
# -------- Running - 125/273 , SID - 33160 - Success - 125 - OCR - --------
# -------- Running - 126/273 , SID - 33406 - Success - 126 - TIKA - --------
# -------- Running - 127/273 , SID - 33564 - Success - 127 - TIKA - --------
# -------- Running - 128/273 , SID - 33791 - Success - 128 - TIKA - --------
# -------- Running - 129/273 , SID - 34037 - Success - 129 - TIKA - --------
# -------- Running - 130/273 , SID - 34122 - Success - 130 - OCR - --------
# -------- Running - 131/273 , SID - 34355 - Success - 131 - OCR - --------
# -------- Running - 132/273 , SID - 34470 - Success - 132 - OCR - --------
# -------- Running - 133/273 , SID - 34647 - Success - 133 - OCR - --------
# -------- Running - 134/273 , SID - 34814 - Success - 134 - OCR - --------
# -------- Running - 135/273 , SID - 34999 - Success - 135 - TIKA - --------
# -------- Running - 136/273 , SID - 35815 - Success - 136 - OCR - --------
# -------- Running - 137/273 , SID - 35816 - Success - 137 - OCR - --------
# -------- Running - 138/273 , SID - 35836 - Success - 138 - TIKA - --------
# -------- Running - 139/273 , SID - 35952 - Success - 139 - OCR - --------
# -------- Running - 140/273 , SID - 36217 - Success - 140 - TIKA - --------
# -------- Running - 141/273 , SID - 36616 - Success - 141 - TIKA - --------
# -------- Running - 142/273 , SID - 37167 - Success - 142 - TIKA - --------
# -------- Running - 143/273 , SID - 37943 - Success - 143 - TIKA - --------
# -------- Running - 144/273 , SID - 38248 - Success - 144 - OCR - --------
# -------- Running - 145/273 , SID - 38295 - Success - 145 - OCR - --------
# -------- Running - 146/273 , SID - 38296 - Success - 146 - OCR - --------
# -------- Running - 147/273 , SID - 38304 - Success - 147 - OCR - --------
# -------- Running - 148/273 , SID - 38330 - Success - 148 - OCR - --------
# -------- Running - 149/273 , SID - 38456 - Success - 149 - OCR - --------
# -------- Running - 150/273 , SID - 38563 - Success - 150 - TIKA - --------
# -------- Running - 151/273 , SID - 38664 - Success - 151 - OCR - --------
# -------- Running - 152/273 , SID - 38846 - Success - 152 - OCR - --------
# -------- Running - 153/273 , SID - 38849 - Success - 153 - OCR - --------
# -------- Running - 154/273 , SID - 38993 - Success - 154 - TIKA - --------
# -------- Running - 155/273 , SID - 39013 - Success - 155 - OCR - --------
# -------- Running - 156/273 , SID - 39076 - Success - 156 - OCR - --------
# -------- Running - 157/273 , SID - 39182 - Success - 157 - OCR - --------
# -------- Running - 158/273 , SID - 39242 - Success - 158 - TIKA - --------
# -------- Running - 159/273 , SID - 39246 - Success - 159 - OCR - --------
# -------- Running - 160/273 , SID - 39356 - Success - 160 - OCR - --------
# -------- Running - 161/273 , SID - 39369 - Success - 161 - TIKA - --------
# -------- Running - 162/273 , SID - 39422 - Failed - 1 -  - --------
# -------- Running - 163/273 , SID - 39424 - Success - 162 - OCR - --------
# -------- Running - 164/273 , SID - 39486 - Success - 163 - OCR - --------
# -------- Running - 165/273 , SID - 39489 - Success - 164 - OCR - --------
# -------- Running - 166/273 , SID - 39498 - Success - 165 - TIKA - --------
# -------- Running - 167/273 , SID - 39510 - Success - 166 - OCR - --------
# -------- Running - 168/273 , SID - 39588 - Success - 167 - OCR - --------
# -------- Running - 169/273 , SID - 39668 - Success - 168 - OCR - --------
# -------- Running - 170/273 , SID - 39674 - Success - 169 - TIKA - --------
# -------- Running - 171/273 , SID - 39889 - Success - 170 - OCR - --------
# -------- Running - 172/273 , SID - 39917 - Success - 171 - TIKA - --------
# -------- Running - 173/273 , SID - 39939 - Success - 172 - TIKA - --------
# -------- Running - 174/273 , SID - 39950 - Success - 173 - TIKA - --------
# -------- Running - 175/273 , SID - 40018 - Success - 174 - OCR - --------
# -------- Running - 176/273 , SID - 40030 - Success - 175 - OCR - --------
# -------- Running - 177/273 , SID - 40125 - Success - 176 - TIKA - --------
# -------- Running - 178/273 , SID - 40133 - Success - 177 - TIKA - --------
# -------- Running - 179/273 , SID - 40212 - Success - 178 - OCR - --------
# -------- Running - 180/273 , SID - 40258 - Success - 179 - OCR - --------
# -------- Running - 181/273 , SID - 40293 - Success - 180 - TIKA - --------
# -------- Running - 182/273 , SID - 40335 - Success - 181 - TIKA - --------
# -------- Running - 183/273 , SID - 40392 - Success - 182 - TIKA - --------
# -------- Running - 184/273 , SID - 40450 - Success - 183 - OCR - --------
# -------- Running - 185/273 , SID - 40490 - Success - 184 - TIKA - --------
# -------- Running - 186/273 , SID - 40493 - Success - 185 - OCR - --------
# -------- Running - 187/273 , SID - 40525 - Success - 186 - OCR - --------
# -------- Running - 188/273 , SID - 40537 - Success - 187 - OCR - --------
# -------- Running - 189/273 , SID - 40553 - Success - 188 - TIKA - --------
# -------- Running - 190/273 , SID - 40557 - Success - 189 - OCR - --------
# -------- Running - 191/273 , SID - 40710 - Success - 190 - OCR - --------
# -------- Running - 192/273 , SID - 40742 - Success - 191 - TIKA - --------
# -------- Running - 193/273 , SID - 40793 - Success - 192 - OCR - --------
# -------- Running - 194/273 , SID - 40885 - Success - 193 - TIKA - --------
# -------- Running - 195/273 , SID - 40887 - Success - 194 - TIKA - --------
# -------- Running - 196/273 , SID - 40896 - Success - 195 - TIKA - --------
# -------- Running - 197/273 , SID - 40925 - Success - 196 - TIKA - --------
# -------- Running - 198/273 , SID - 40987 - Success - 197 - TIKA - --------
# -------- Running - 199/273 , SID - 41105 - Success - 198 - TIKA - --------
# -------- Running - 200/273 , SID - 41106 - Success - 199 - OCR - --------
# -------- Running - 201/273 , SID - 41157 - Success - 200 - OCR - --------
# -------- Running - 202/273 , SID - 41195 - Success - 201 - TIKA - --------
# -------- Running - 203/273 , SID - 41266 - Success - 202 - TIKA - --------
# -------- Running - 204/273 , SID - 41295 - Success - 203 - TIKA - --------
# -------- Running - 205/273 , SID - 41299 - Success - 204 - TIKA - --------
# -------- Running - 206/273 , SID - 41319 - Success - 205 - OCR - --------
# -------- Running - 207/273 , SID - 41343 - Success - 206 - OCR - --------
# -------- Running - 208/273 , SID - 41373 - Success - 207 - TIKA - --------
# -------- Running - 209/273 , SID - 41472 - Success - 208 - TIKA - --------
# -------- Running - 210/273 , SID - 41538 - Success - 209 - OCR - --------
# -------- Running - 211/273 , SID - 41545 - Success - 210 - TIKA - --------
# -------- Running - 212/273 , SID - 41627 - Success - 211 - OCR - --------
# -------- Running - 213/273 , SID - 41665 - Success - 212 - TIKA - --------
# -------- Running - 214/273 , SID - 41673 - Success - 213 - TIKA - --------
# -------- Running - 215/273 , SID - 41700 - Success - 214 - TIKA - --------
# -------- Running - 216/273 , SID - 41724 - Success - 215 - OCR - --------
# -------- Running - 217/273 , SID - 41880 - Success - 216 - TIKA - --------
# -------- Running - 218/273 , SID - 42007 - Success - 217 - OCR - --------
# -------- Running - 219/273 , SID - 42012 - Success - 218 - TIKA - --------
# -------- Running - 220/273 , SID - 42088 - Success - 219 - TIKA - --------
# -------- Running - 221/273 , SID - 42190 - Success - 220 - TIKA - --------
# -------- Running - 222/273 , SID - 42271 - Success - 221 - OCR - --------
# -------- Running - 223/273 , SID - 42392 - Success - 222 - OCR - --------
# -------- Running - 224/273 , SID - 42408 - Success - 223 - TIKA - --------
# -------- Running - 225/273 , SID - 42504 - Success - 224 - TIKA - --------
# -------- Running - 226/273 , SID - 42664 - Success - 225 - TIKA - --------
# -------- Running - 227/273 , SID - 42667 - Success - 226 - OCR - --------
# -------- Running - 228/273 , SID - 42787 - Success - 227 - OCR - --------
# -------- Running - 229/273 , SID - 42798 - Success - 228 - TIKA - --------
# -------- Running - 230/273 , SID - 42821 - Success - 229 - OCR - --------
# -------- Running - 231/273 , SID - 43025 - Success - 230 - TIKA - --------
# -------- Running - 232/273 , SID - 43044 - Success - 231 - TIKA - --------
# -------- Running - 233/273 , SID - 43049 - Success - 232 - TIKA - --------
# -------- Running - 234/273 , SID - 43055 - Success - 233 - OCR - --------
# -------- Running - 235/273 , SID - 43071 - Success - 234 - OCR - --------
# -------- Running - 236/273 , SID - 43104 - Success - 235 - TIKA - --------
# -------- Running - 237/273 , SID - 43278 - Success - 236 - TIKA - --------
# -------- Running - 238/273 , SID - 43279 - Success - 237 - TIKA - --------
# -------- Running - 239/273 , SID - 43300 - Success - 238 - TIKA - --------
# -------- Running - 240/273 , SID - 43340 - Success - 239 - OCR - --------
# -------- Running - 241/273 , SID - 43366 - Success - 240 - TIKA - --------
# -------- Running - 242/273 , SID - 43498 - Success - 241 - OCR - --------
# -------- Running - 243/273 , SID - 43557 - Success - 242 - OCR - --------
# -------- Running - 244/273 , SID - 43837 - Success - 243 - OCR - --------
# -------- Running - 245/273 , SID - 43893 - Success - 244 - TIKA - --------
# -------- Running - 246/273 , SID - 43896 - Success - 245 - OCR - --------
# -------- Running - 247/273 , SID - 43965 - Success - 246 - TIKA - --------
# -------- Running - 248/273 , SID - 44002 - Success - 247 - TIKA - --------
# -------- Running - 249/273 , SID - 44036 - Success - 248 - OCR - --------
# -------- Running - 250/273 , SID - 44278 - Success - 249 - TIKA - --------
# -------- Running - 251/273 , SID - 44490 - Success - 250 - TIKA - --------
# -------- Running - 252/273 , SID - 44512 - Success - 251 - TIKA - --------
# -------- Running - 253/273 , SID - 44517 - Success - 252 - OCR - --------
# -------- Running - 254/273 , SID - 44548 - Success - 253 - OCR - --------
# -------- Running - 255/273 , SID - 44664 - Success - 254 - TIKA - --------
# -------- Running - 256/273 , SID - 44796 - Success - 255 - TIKA - --------
# -------- Running - 257/273 , SID - 44941 - Success - 256 - TIKA - --------
# -------- Running - 258/273 , SID - 44965 - Success - 257 - OCR - --------
# -------- Running - 259/273 , SID - 44968 - Success - 258 - TIKA - --------
# -------- Running - 260/273 , SID - 8796 - Success - 259 - TIKA - --------
# -------- Running - 261/273 , SID - 8811 - Success - 260 - TIKA - --------
# -------- Running - 262/273 , SID - 9010 - Success - 261 - TIKA - --------
# -------- Running - 263/273 , SID - 9021 - Success - 262 - OCR - --------
# -------- Running - 264/273 , SID - 9099 - Success - 263 - TIKA - --------
# -------- Running - 265/273 , SID - 9280 - Success - 264 - OCR - --------
# -------- Running - 266/273 , SID - 9389 - Success - 265 - OCR - --------
# -------- Running - 267/273 , SID - 9541 - Success - 266 - TIKA - --------
# -------- Running - 268/273 , SID - 9686 - Success - 267 - OCR - --------
# -------- Running - 269/273 , SID - 9698 - Success - 268 - TIKA - --------
# -------- Running - 270/273 , SID - 9749 - Success - 269 - OCR - --------
# -------- Running - 271/273 , SID - 9750 - Success - 270 - OCR - --------
# -------- Running - 272/273 , SID - 9766 - Success - 271 - TIKA - --------
# -------- Running - 273/273 , SID - 9870 - Success - 272 - OCR - --------

# %%
sid = 9010

# %%
extract_text_from_pdf_using_tika(f"{PDF_PATH}\\SID-{sid}.pdf")

# %%
extract_text_from_pdf_using_ocr(f"{PDF_PATH}\\SID-{sid}.pdf")

# %%
path.getsize(f"E:\\Projects\\modern_slavery_registry\\data\\slavery_texts\\SID-{sid}.txt")

# %%
get_pdf_url_from_sid(sid)
